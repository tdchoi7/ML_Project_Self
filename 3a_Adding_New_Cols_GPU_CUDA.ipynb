# %%
# import numpy as np
# import pandas as pd
# pd.set_option('display.max_columns', None)

# import sklearn
# from sklearn import model_selection as ms
# sklearn.set_config(print_changed_only=False)

# from sklearn.preprocessing import OneHotEncoder
# from sklearn.preprocessing import MinMaxScaler
# from sklearn.linear_model import Ridge, Lasso, ElasticNet, LinearRegression
# from sklearn.ensemble import GradientBoostingRegressor, RandomForestRegressor
# from sklearn.model_selection import GridSearchCV
# from sklearn import linear_model as lm

import cupy as cp
import cudf
import cuml
from cuml.linear_model import Ridge, Lasso, ElasticNet, LinearRegression
from cuml.ensemble import RandomForestRegressor
from cuml.metrics.regression import mean_squared_error
# from cuml.preprocessing import OneHotEncoder
# from cuml.preprocessing import MinMaxScaler
# from cuml import train_test_split as cutts

import dask_ml
import dask_ml.model_selection as dcv
# from dask_ml.preprocessing import DummyEncoder
# from dask_ml.preprocessing import Categorizer
# from dask_ml.preprocessing import OneHotEncoder
from dask_ml.preprocessing import MinMaxScaler

import xgboost

import copy

import itertools

import re

import math

import import_ipynb

from _Self_Written_Functions_Sheet import (conditions_edit, nbrhd_rank, drop_nbrhd,
totallivsf_add, drop_grlivarea, bsmtfin_add, drop_bsmtfinsf12, totalporchsf_add,
drop_porches, yrsremodtosold_add, drop_yrsoldremod, fireplace_yes, drop_fireplaces,
pool_yes, drop_poolarea, totalbaths_add, drop_baths, totalbsmtbaths_add,
drop_bsmtbaths)

from _Self_Written_Functions_Sheet import use_og_data, comb_list_generator, rmse
# dum_scale, 

from _Self_Written_Functions_Sheet_CUDA import cu_rmse
# Out:
# importing Jupyter notebook from _Self_Written_Functions_Sheet.ipynb
# importing Jupyter notebook from _Self_Written_Functions_Sheet_CUDA.ipynb

# %%
# importing the datasets
hp_train = cudf.read_csv('Proj3_Datasets/hp_2a_ranked_edited_train.csv', index_col=0)
hp_test = cudf.read_csv('Proj3_Datasets/hp_2a_ranked_edited_test.csv', index_col=0)
hp_logsp = cudf.read_csv('Proj3_Datasets/hp_1a_no_imputation_logsaleprice.csv',
                                index_col=0)
hp_saleprice = cudf.read_csv('Proj3_Datasets/hp_1a_no_imputation_saleprice.csv')

# saving train index
hp_index = hp_train.index

combo_nonedit = cudf.concat([hp_train, hp_test])
combo_nonedit.columns = hp_train.columns

# convert all possible numeric types to numeric
for col in combo_nonedit.columns: 
    combo_nonedit[col] = combo_nonedit[col].astype('float', errors='ignore')

combo_cols = list(combo_nonedit.columns)

combo = copy.deepcopy(combo_nonedit)

# %%
# hp_touse = dum_scale(combo).loc[hp_index]
# hp_w_sale = cudf.concat([hp_touse, hp_logsp], axis=1)

# xtrain, xtest, ytrain, ytest = cuml.model_selection.train_test_split(hp_w_sale, 
#                                                                              'SalePrice',
#                                                                              train_size=0.8,
#                                                                              random_state=0)

# %%
# lm = cuml.LinearRegression()
# # parameters to use
# fitintercept = [True, False]
# gparam_mlr_1 = {'fit_intercept': fitintercept}
# # setting parameters
# gs_mlr_1 = dcv.GridSearchCV(lm, gparam_mlr_1, cv=5, refit=True, return_train_score=True)
# gs_mlr_1.fit(xtrain, ytrain)
# mlr_model.test_rmse = cu_rmse(gs_mlr_1, ytest, xtest)
# mlr_model.test_rmse

# %%
# def mlr_model(x_trn, y_trn, x_tst, y_tst):
#     lm = cuml.LinearRegression()
#     # parameters to use
#     fitintercept = [True, False]
#     gparam_mlr_1 = {'fit_intercept': fitintercept}
#     # setting parameters
#     gs_mlr_1 = dcv.GridSearchCV(lm, gparam_mlr_1, cv=5, refit=True, return_train_score=True)
#     gs_mlr_1.fit(x_trn, y_trn)
#     mlr_model.test_rmse = math.sqrt(mean_squared_error(actual, 
#                                                      model.best_estimator_.predict(features)))    
    
# def lasso_model(x_trn, y_trn, x_tst, y_tst):
#     lasso = Lasso(max_iter=1000000)
#     # parameters to use
#     alphas = [0.0001, 0.000112, 0.000124, 0.000136, 0.000148]
#     fitintercept = [True, False]
#     selec = ['cyclic', 'random']
#     gparam_lasso_1 = {'alpha': alphas,
#                       'fit_intercept':fitintercept,
#                       'selection': selec}
#     # setting parameters
#     gs_lasso_1 = dcv.GridSearchCV(lasso, gparam_lasso_1, refit=True, cv=5,
#                                  return_train_score=True)
#     gs_lasso_1.fit(x_trn, y_trn)
#     lasso_model.test_rmse = cu_rmse(gs_lasso_1, y_tst, x_tst)

# def ridge_model(x_trn, y_trn, x_tst, y_tst):
#     ridge = Ridge(random_state=state, max_iter=10000, fit_intercept=True)
#     # parameters to use
#     solvers = ['auto', 'svd', 'cholesky', 'lsqr', 'sparse_cg', 'sag', 'saga', 'lbfgs']
#     fitintercept = [True, False]
#     gparam_ridge_1 = {'solver': solvers,
#                       'fit_intercept': fitintercept, 
#                       'random_state': [state]}
#     # setting parameters
#     gs_ridge_1 = dcv.GridSearchCV(ridge, gparam_ridge_1,refit=True, n_jobs=-1,
#                                  scoring='neg_root_mean_squared_error',
#                                  return_train_score=True)
#     gs_ridge_1.fit(x_trn, y_trn)
#     ridge_model.test_rmse = cu_rmse(gs_ridge_1, y_tst, x_tst)
    
# def enet_model(x_trn, y_trn, x_tst, y_tst):
#     enet = ElasticNet(max_iter=10000000, selection='random')
#     # parameters to use
#     alphas = [1e-4, 2.5e-4, 5e-4]
#     l1ratio = [0.5, 0.7, 1]
#     precomputes = [True, False]
#     warmstart = [True, False]
#     fitintercept = [True, False]
#     gparam_enet_1 = {'alpha': alphas,
#                      'l1_ratio': l1ratio,
#                      'precompute': precomputes, 
#                      'warm_start': warmstart,
#                      'fit_intercept': fitintercept}
#     # setting parameters
#     gs_enet_1 = dcv.GridSearchCV(enet, gparam_enet_1, refit=True, cv=5,
#                                  return_train_score=True)
#     gs_enet_1.fit(x_trn, y_trn)
#     enet_model.test_rmse = cu_rmse(gs_enet_1, y_tst, x_tst)
    
# def rfr_model(x_trn, y_trn, x_tst, y_tst):
#     rfr = RandomForestRegressor()
#     gparam_rfr = {}
#     # setting parameters
#     gs_rfr = dcv.GridSearchCV(rfr, gparam_rfr,refit=True, cv=5, return_train_score=True)
#     gs_rfr.fit(x_trn, y_trn)
#     rfr_model.test_rmse = cu_rmse(gs_rfr, y_tst, x_tst)
    
# def gbm_model(x_trn, y_trn, x_tst, y_tst):
#     gbm = GradientBoostingRegressor()
#     gparam_gbm = {}
#     gs_gbm = dcv.GridSearchCV(gbm, gparam_gbm,refit=True, n_jobs=-1,
#                           scoring='neg_root_mean_squared_error', return_train_score=True)
#     gs_gbm.fit(x_trn, y_trn)
#     gbm_model.test_rmse = cu_rmse(gs_gbm, y_tst, x_tst)
    
def xgb_model(x_trn, y_trn, x_tst, y_tst):
    xgb_t = xgboost.XGBRegressor()
    gparam_xgb_t = {}
    gs_xgb_t = dcv.GridSearchCV(xgb_t, gparam_xgb_t,refit=True, cv=5,
                                return_train_score=True)
    gs_xgb_t.fit(x_trn, y_trn)
    xgb_model.test_rmse = cu_rmse(gs_xgb_t, y_tst, x_tst)

# %%
hp = copy.deepcopy(combo_nonedit)
state = 0
counter = 0

# using standard kfold split
n_folds = dcv.KFold(n_splits=5, random_state=state, shuffle=True)

# lists of the functions separated by whether something is changed or added
stuff_add = [nbrhd_rank, totallivsf_add, bsmtfin_add, totalporchsf_add, 
             yrsremodtosold_add, fireplace_yes, pool_yes, totalbaths_add,
             totalbsmtbaths_add, conditions_edit]

# list of functions that will drop columns
stuff_drop = [drop_nbrhd, drop_grlivarea, drop_bsmtfinsf12,  drop_porches,
              drop_yrsoldremod, drop_fireplaces, drop_poolarea,
              drop_baths, drop_bsmtbaths]

# list of models to use
models = [xgb_model]
# mlr_model, lasso_model,  enet_model, rfr_model, gbm_model,

# using self-written function to generate permutations of 2 powersets
# looking at the max length
len(comb_list_generator(stuff_add, stuff_drop))
# Out:
# 92378

# %%
# def dum_scale(df):
#     '''
#     dummify and scale the input dataset
#     '''
#     # dummify the variables
#     hp_dum = pd.get_dummies(df, drop_first=True)
#     hp_dum_cols = list(hp_dum.columns)
#     # scale the dataset
#     for col in hp_dum_cols:
#         hp_dum[col] = MinMaxScaler().fit_transform(np.array(hp_dum[col]).reshape(-1,1))
#         hp_dum.columns = hp_dum_cols
#     hp_dum_scale = copy.deepcopy(hp_dum)
#     return hp_dum_scale

# %%
def dum_scale(df):
    # dummify the variables
    hp_dum = cudf.get_dummies(df)
    '''
    since cuML's get_dummies does not yet support drop_first,
    I wrote this as a part of the function that would drop 
    the column with the highest count of 1s rather than dropping
    the first (it was easier)
    '''
    obj_list = [string for string in hp_dum.columns if '_' in string]
    cols_tracker = []
    to_drop_list = []

    for feat in obj_list:
        # we are assuming that dummification has already occurred
        # and that we are using the dummified hp_dum to figure out which
        # columns to delete
        feat_sp = str(feat.split('_')[0])
        if feat_sp in cols_tracker:
            continue
        else:
            # this gives us the original features that were dummified
            cols_tracker.append(feat_sp)

    for sub_cols in cols_tracker:
        # reusing a dictionary to get the key of the highest value
        tracker_sum = {}
        cols = [col for col in hp_dum.columns if sub_cols in col]
        # heatingqc can get accidentally inserted into this dictionary
        if 'HeatingQC' in cols:
            cols.remove('HeatingQC')
        for col in cols:
            # the value will be the sum of the column in order to find
            # the max
            tracker_sum[col] = hp_dum[col].sum()
        to_drop = max(tracker_sum, key=tracker_sum.get)
        # the max gets added to the list to drop
        to_drop_list.append(to_drop)

    hp_dum_dp = hp_dum.drop(to_drop_list, axis=1)
    hp_dum_dp_cols = list(hp_dum_dp.columns)
    
    for col in hp_dum_dp_cols:
        hp_dum_dp[col] = MinMaxScaler().fit_transform(cp.array(hp_dum_dp[col]).reshape(-1,1))
        hp_dum_dp.columns = hp_dum_dp_cols
    return hp_dum_dp

# %%
# numbers will be indices later down
funcs_scores = {1: {}, 2: {}, 3: {}, 4: {}, 5: {}, 6: {}}

def apply_comb_list(com_list):
    counter = 0
    for cb_list in com_list:

        combo = copy.deepcopy(combo_nonedit)

        # converting any numbers to numeric type
        for col in combo.columns: 
            combo[col] = combo[col].astype('float', errors='ignore')

        # converting these 2 cols to string bc difficulties wi/ OneHotEncoding using Dask
        mo_yr = ['MoSold', 'YrSold']
        for my in mo_yr:
            if my in combo.columns:
                combo[[my]] = combo[[my]].astype(str)
        
        # converting the single string within the list to a list of strings
        cb_split = re.sub("['']", "", str(cb_list)).strip('][').split(', ')
        # converting the list of strings to a single string
        funcs_used = ', '.join(cb_split)
        
        # calling all of the functions within the list
        for cb in cb_split:
            eval(cb)(combo)
        
        # getting the train dataset for modeling after dummification
        hp_touse = dum_scale(combo).loc[hp_index]
        hp_w_sale = cudf.concat([hp_touse, hp_logsp], axis=1)

        # setting up train and test sets
        xtrain, xtest, ytrain, ytest = cuml.model_selection.train_test_split(hp_w_sale, 
                                                                             'SalePrice',
                                                                             train_size=0.8,
                                                                             random_state=0)
        # Must flatten to fit
        ytrain = ytrain.values.flatten()

        # run the models
        for i, model in enumerate(models):
            model(xtrain, ytrain, xtest, ytest)
            # each model has a designated number (the order in the list: models)
            i+=1
            # add scores to the dictionary of dictionaries
            funcs_scores[i][funcs_used] = model.test_rmse
        
        # keeping track of rounds
        counter += 1
        print(f'Completed round {counter}')
    return funcs_scores

# %%
apply_comb_list(comb_list_generator(stuff_add, stuff_drop))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_18667/2517412720.py in <module>
# ----> 1 apply_comb_list(comb_list_generator(stuff_add, stuff_drop))
#
# /tmp/ipykernel_18667/1711827688.py in apply_comb_list(com_list)
#      41         # run the models
#      42         for i, model in enumerate(models):
# ---> 43             model(xtrain, ytrain, xtest, ytest)
#      44             # each model has a designated number (the order in the list: models)
#      45             i+=1
#
# /tmp/ipykernel_18667/3666223641.py in xgb_model(x_trn, y_trn, x_tst, y_tst)
#      80     gs_xgb_t = dcv.GridSearchCV(xgb_t, gparam_xgb_t,refit=True, cv=5,
#      81                                 return_train_score=True)
# ---> 82     gs_xgb_t.fit(x_trn, y_trn)
#      83     xgb_model.test_rmse = cu_rmse(gs_xgb_t, y_tst, x_tst)
#
# ~/anaconda3/envs/rapids-21.10/lib/python3.7/site-packages/dask_ml/model_selection/_search.py in fit(self, X, y, groups, **fit_params)
#    1275             out = [result_map[k] for k in keys]
#    1276         else:
# -> 1277             out = scheduler(dsk, keys, num_workers=n_jobs)
#    1278
#    1279         if self.iid:
#
# ~/anaconda3/envs/rapids-21.10/lib/python3.7/site-packages/dask/threaded.py in get(dsk, result, cache, num_workers, pool, **kwargs)
#      85         get_id=_thread_get_id,
#      86         pack_exception=pack_exception,
# ---> 87         **kwargs
#      88     )
#      89
#
# ~/anaconda3/envs/rapids-21.10/lib/python3.7/site-packages/dask/local.py in get_async(submit, num_workers, dsk, result, cache, get_id, rerun_exceptions_locally, pack_exception, raise_exception, callbacks, dumps, loads, chunksize, **kwargs)
#     515                             _execute_task(task, data)  # Re-execute locally
#     516                         else:
# --> 517                             raise_exception(exc, tb)
#     518                     res, worker_id = loads(res_info)
#     519                     state["cache"][key] = res
#
# ~/anaconda3/envs/rapids-21.10/lib/python3.7/site-packages/dask/local.py in reraise(exc, tb)
#     323     if exc.__traceback__ is not tb:
#     324         raise exc.with_traceback(tb)
# --> 325     raise exc
#     326
#     327
#
# ~/anaconda3/envs/rapids-21.10/lib/python3.7/site-packages/dask/local.py in execute_task(key, task_info, dumps, loads, get_id, pack_exception)
#     221     try:
#     222         task, data = loads(task_info)
# --> 223         result = _execute_task(task, data)
#     224         id = get_id()
#     225         result = dumps((result, id))
#
# ~/anaconda3/envs/rapids-21.10/lib/python3.7/site-packages/dask/core.py in _execute_task(arg, cache, dsk)
#     119         # temporaries by their reference count and can execute certain
#     120         # operations in-place.
# --> 121         return func(*(_execute_task(a, cache) for a in args))
#     122     elif not ishashable(arg):
#     123         return arg
#
# ~/anaconda3/envs/rapids-21.10/lib/python3.7/site-packages/dask_ml/model_selection/methods.py in fit_and_score(est, cv, X, y, n, scorer, error_score, fields, params, fit_params, return_train_score)
#     319         X_train = y_train = None
#     320
# --> 321     return score(est_and_time, X_test, y_test, X_train, y_train, scorer, error_score)
#     322
#     323
#
# ~/anaconda3/envs/rapids-21.10/lib/python3.7/site-packages/dask_ml/model_selection/methods.py in score(est_and_time, X_test, y_test, X_train, y_train, scorer, error_score)
#     284     start_time = default_timer()
#     285     try:
# --> 286         test_score = _score(est, X_test, y_test, scorer)
#     287     except Exception:
#     288         if error_score == "raise":
#
# ~/anaconda3/envs/rapids-21.10/lib/python3.7/site-packages/dask_ml/model_selection/methods.py in _score(est, X, y, scorer)
#     277     if isinstance(scorer, Mapping):
#     278         return {k: v(est, X) if y is None else v(est, X, y) for k, v in scorer.items()}
# --> 279     return scorer(est, X) if y is None else scorer(est, X, y)
#     280
#     281
#
# ~/anaconda3/envs/rapids-21.10/lib/python3.7/site-packages/sklearn/metrics/_scorer.py in _passthrough_scorer(estimator, *args, **kwargs)
#     416 def _passthrough_scorer(estimator, *args, **kwargs):
#     417     """Function that wraps estimator.score"""
# --> 418     return estimator.score(*args, **kwargs)
#     419
#     420
#
# ~/anaconda3/envs/rapids-21.10/lib/python3.7/site-packages/sklearn/base.py in score(self, X, y, sample_weight)
#     699
#     700         y_pred = self.predict(X)
# --> 701         return r2_score(y, y_pred, sample_weight=sample_weight)
#     702
#     703     def _more_tags(self):
#
# ~/anaconda3/envs/rapids-21.10/lib/python3.7/site-packages/sklearn/metrics/_regression.py in r2_score(y_true, y_pred, sample_weight, multioutput)
#     773     """
#     774     y_type, y_true, y_pred, multioutput = _check_reg_targets(
# --> 775         y_true, y_pred, multioutput
#     776     )
#     777     check_consistent_length(y_true, y_pred, sample_weight)
#
# ~/anaconda3/envs/rapids-21.10/lib/python3.7/site-packages/sklearn/metrics/_regression.py in _check_reg_targets(y_true, y_pred, multioutput, dtype)
#      88     """
#      89     check_consistent_length(y_true, y_pred)
# ---> 90     y_true = check_array(y_true, ensure_2d=False, dtype=dtype)
#      91     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#      92
#
# ~/anaconda3/envs/rapids-21.10/lib/python3.7/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     736                     array = array.astype(dtype, casting="unsafe", copy=False)
#     737                 else:
# --> 738                     array = np.asarray(array, order=order, dtype=dtype)
#     739             except ComplexWarning as complex_warning:
#     740                 raise ValueError(
#
# cupy/_core/core.pyx in cupy._core.core.ndarray.__array__()
#
# TypeError: Implicit conversion to a NumPy array is not allowed. Please use `.get()` to construct a NumPy array explicitly.

# %%
funcs_scores

# %%
for k_1 in funcs_scores:
    k_min = min(funcs_scores[k_1], key=funcs_scores[k_1].get)
    v_min = funcs_scores[k_1][k_min]
    print(k_1)
    print(k_min)
    print(v_min) 
    print('#' * 50)
