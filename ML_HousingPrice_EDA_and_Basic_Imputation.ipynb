# %% [markdown]
# # NYCDSA Machine Learning Project - House Prices
#
# For this project, the primary task is to employ machine learning techniques to accurately make predictions given a dataset. The framework will be through the lens of the House Prices: Advanced Regression Techniques from Kaggle. While the primary goal of Kaggle competitions is generally focused on predictive accuracy, it expected to lead the audience through descriptive insights as well. For the purposes of the project, aim is to not only create a model that predicts well, but also to describe data insights drawn from exploration.

# %%
# xmodel=xgb.XGBRegressor(nthread= -1,gpu_id=-1)
# # set the parameter grid
# grid_para = {'min_child_weight': [1,2], # default = 1
#              'gamma': [0, 0.025, 0.055, 0.075], # default = 0
#              'reg_alpha': [0], # default = 0
#              "learning_rate": [0.05, 0.078, 0.1], #  default=0.3
#              'subsample': [0.2,0.3,0.4], # default =1
#              'colsample_bytree': [0.4, 0.5, 0.6], # default =1
#              'max_depth': [2,3,4], # default =6
#              "n_estimators": [100,125,137,150],
#              'random_state' :[1]
# }
# # run the XGB regressor through the grid search
# grid_search_xmodel = ms.GridSearchCV(xmodel, grid_para, scoring='neg_root_mean_squared_error', cv=5, n_jobs= -1, verbose=4)
# grid_search_xmodel.fit(Xu_train, yu_train)

# %%
import numpy as np
import pandas as pd
pd.set_option('display.max_columns', None)

from collections import Counter

import seaborn as sns
import matplotlib.pyplot as plt

import sklearn
from sklearn.linear_model import Ridge, Lasso, ElasticNet, LinearRegression
from sklearn.feature_selection import chi2, f_regression, f_classif, mutual_info_classif, mutual_info_regression 
from sklearn.feature_selection import SelectKBest, SelectFromModel, VarianceThreshold
from sklearn.impute import KNNImputer
from sklearn.model_selection import GridSearchCV
from sklearn import linear_model as lm
from sklearn import neighbors
from sklearn import ensemble
from sklearn import model_selection as ms
sklearn.set_config(print_changed_only=False)

from matplotlib import pyplot as plt

from ipynb.fs.full.functions_sheet import col_obj_list, nan_col_list, cols_nan_unique, nan_col_obj_list_fillna, fill_masvnrtype

# %% [markdown]
# # Data Exploration

# %%
hp_w_outcome = pd.read_csv('../train.csv')

# %%
hp_w_outcome.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 0       Norm     1Fam     2Story            7            5       2003
# 1       Norm     1Fam     1Story            6            8       1976
# 2       Norm     1Fam     2Story            7            5       2001
# 3       Norm     1Fam     2Story            7            5       1915
# 4       Norm     1Fam     2Story            8            5       2000
#
#    YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 0          2003     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 1          1976     Gable  CompShg     MetalSd     MetalSd       None
# 2          2002     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 3          1970     Gable  CompShg     Wd Sdng     Wd Shng       None
# 4          2000     Gable  CompShg     VinylSd     VinylSd    BrkFace
#
#    MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond BsmtExposure  \
# 0       196.0        Gd        TA      PConc       Gd       TA           No
# 1         0.0        TA        TA     CBlock       Gd       TA           Gd
# 2       162.0        Gd        TA      PConc       Gd       TA           Mn
# 3         0.0        TA        TA     BrkTil       TA       Gd           No
# 4       350.0        Gd        TA      PConc       Gd       TA           Av
#
#   BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  \
# 0          GLQ         706          Unf           0        150          856
# 1          ALQ         978          Unf           0        284         1262
# 2          GLQ         486          Unf           0        434          920
# 3          ALQ         216          Unf           0        540          756
# 4          GLQ         655          Unf           0        490         1145
#
#   Heating HeatingQC CentralAir Electrical  1stFlrSF  2ndFlrSF  LowQualFinSF  \
# 0    GasA        Ex          Y      SBrkr       856       854             0
# 1    GasA        Ex          Y      SBrkr      1262         0             0
# 2    GasA        Ex          Y      SBrkr       920       866             0
# 3    GasA        Gd          Y      SBrkr       961       756             0
# 4    GasA        Ex          Y      SBrkr      1145      1053             0
#
#    GrLivArea  BsmtFullBath  BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  \
# 0       1710             1             0         2         1             3
# 1       1262             0             1         2         0             3
# 2       1786             1             0         2         1             3
# 3       1717             1             0         1         0             3
# 4       2198             1             0         2         1             4
#
#    KitchenAbvGr KitchenQual  TotRmsAbvGrd Functional  Fireplaces FireplaceQu  \
# 0             1          Gd             8        Typ           0         NaN
# 1             1          TA             6        Typ           1          TA
# 2             1          Gd             6        Typ           1          TA
# 3             1          Gd             7        Typ           1          Gd
# 4             1          Gd             9        Typ           1          TA
#
#   GarageType  GarageYrBlt GarageFinish  GarageCars  GarageArea GarageQual  \
# 0     Attchd       2003.0          RFn           2         548         TA
# 1     Attchd       1976.0          RFn           2         460         TA
# 2     Attchd       2001.0          RFn           2         608         TA
# 3     Detchd       1998.0          Unf           3         642         TA
# 4     Attchd       2000.0          RFn           3         836         TA
#
#   GarageCond PavedDrive  WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  \
# 0         TA          Y           0           61              0          0
# 1         TA          Y         298            0              0          0
# 2         TA          Y           0           42              0          0
# 3         TA          Y           0           35            272          0
# 4         TA          Y         192           84              0          0
#
#    ScreenPorch  PoolArea PoolQC Fence MiscFeature  MiscVal  MoSold  YrSold  \
# 0            0         0    NaN   NaN         NaN        0       2    2008
# 1            0         0    NaN   NaN         NaN        0       5    2007
# 2            0         0    NaN   NaN         NaN        0       9    2008
# 3            0         0    NaN   NaN         NaN        0       2    2006
# 4            0         0    NaN   NaN         NaN        0      12    2008
#
#   SaleType SaleCondition  SalePrice
# 0       WD        Normal     208500
# 1       WD        Normal     181500
# 2       WD        Normal     223500
# 3       WD       Abnorml     140000
# 4       WD        Normal     250000

# %%
hp_saleprice = hp_w_outcome[['SalePrice']]

hp = hp_w_outcome.drop(['SalePrice'], axis=1)

# %%
hp
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0            Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1            Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2            Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3            Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4            Lvl    AllPub       FR2       Gtl      NoRidge       Norm
# ...          ...       ...       ...       ...          ...        ...
# 1455         Lvl    AllPub    Inside       Gtl      Gilbert       Norm
# 1456         Lvl    AllPub    Inside       Gtl       NWAmes       Norm
# 1457         Lvl    AllPub    Inside       Gtl      Crawfor       Norm
# 1458         Lvl    AllPub    Inside       Gtl        NAmes       Norm
# 1459         Lvl    AllPub    Inside       Gtl      Edwards       Norm
#
#      Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 0          Norm     1Fam     2Story            7            5       2003
# 1          Norm     1Fam     1Story            6            8       1976
# 2          Norm     1Fam     2Story            7            5       2001
# 3          Norm     1Fam     2Story            7            5       1915
# 4          Norm     1Fam     2Story            8            5       2000
# ...         ...      ...        ...          ...          ...        ...
# 1455       Norm     1Fam     2Story            6            5       1999
# 1456       Norm     1Fam     1Story            6            6       1978
# 1457       Norm     1Fam     2Story            7            9       1941
# 1458       Norm     1Fam     1Story            5            6       1950
# 1459       Norm     1Fam     1Story            5            6       1965
#
#       YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 0             2003     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 1             1976     Gable  CompShg     MetalSd     MetalSd       None
# 2             2002     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 3             1970     Gable  CompShg     Wd Sdng     Wd Shng       None
# 4             2000     Gable  CompShg     VinylSd     VinylSd    BrkFace
# ...            ...       ...      ...         ...         ...        ...
# 1455          2000     Gable  CompShg     VinylSd     VinylSd       None
# 1456          1988     Gable  CompShg     Plywood     Plywood      Stone
# 1457          2006     Gable  CompShg     CemntBd     CmentBd       None
# 1458          1996       Hip  CompShg     MetalSd     MetalSd       None
# 1459          1965     Gable  CompShg     HdBoard     HdBoard       None
#
#       MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond  \
# 0          196.0        Gd        TA      PConc       Gd       TA
# 1            0.0        TA        TA     CBlock       Gd       TA
# 2          162.0        Gd        TA      PConc       Gd       TA
# 3            0.0        TA        TA     BrkTil       TA       Gd
# 4          350.0        Gd        TA      PConc       Gd       TA
# ...          ...       ...       ...        ...      ...      ...
# 1455         0.0        TA        TA      PConc       Gd       TA
# 1456       119.0        TA        TA     CBlock       Gd       TA
# 1457         0.0        Ex        Gd      Stone       TA       Gd
# 1458         0.0        TA        TA     CBlock       TA       TA
# 1459         0.0        Gd        TA     CBlock       TA       TA
#
#      BsmtExposure BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  \
# 0              No          GLQ         706          Unf           0
# 1              Gd          ALQ         978          Unf           0
# 2              Mn          GLQ         486          Unf           0
# 3              No          ALQ         216          Unf           0
# 4              Av          GLQ         655          Unf           0
# ...           ...          ...         ...          ...         ...
# 1455           No          Unf           0          Unf           0
# 1456           No          ALQ         790          Rec         163
# 1457           No          GLQ         275          Unf           0
# 1458           Mn          GLQ          49          Rec        1029
# 1459           No          BLQ         830          LwQ         290
#
#       BsmtUnfSF  TotalBsmtSF Heating HeatingQC CentralAir Electrical  \
# 0           150          856    GasA        Ex          Y      SBrkr
# 1           284         1262    GasA        Ex          Y      SBrkr
# 2           434          920    GasA        Ex          Y      SBrkr
# 3           540          756    GasA        Gd          Y      SBrkr
# 4           490         1145    GasA        Ex          Y      SBrkr
# ...         ...          ...     ...       ...        ...        ...
# 1455        953          953    GasA        Ex          Y      SBrkr
# 1456        589         1542    GasA        TA          Y      SBrkr
# 1457        877         1152    GasA        Ex          Y      SBrkr
# 1458          0         1078    GasA        Gd          Y      FuseA
# 1459        136         1256    GasA        Gd          Y      SBrkr
#
#       1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  BsmtFullBath  BsmtHalfBath  \
# 0          856       854             0       1710             1             0
# 1         1262         0             0       1262             0             1
# 2          920       866             0       1786             1             0
# 3          961       756             0       1717             1             0
# 4         1145      1053             0       2198             1             0
# ...        ...       ...           ...        ...           ...           ...
# 1455       953       694             0       1647             0             0
# 1456      2073         0             0       2073             1             0
# 1457      1188      1152             0       2340             0             0
# 1458      1078         0             0       1078             1             0
# 1459      1256         0             0       1256             1             0
#
#       FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr KitchenQual  \
# 0            2         1             3             1          Gd
# 1            2         0             3             1          TA
# 2            2         1             3             1          Gd
# 3            1         0             3             1          Gd
# 4            2         1             4             1          Gd
# ...        ...       ...           ...           ...         ...
# 1455         2         1             3             1          TA
# 1456         2         0             3             1          TA
# 1457         2         0             4             1          Gd
# 1458         1         0             2             1          Gd
# 1459         1         1             3             1          TA
#
#       TotRmsAbvGrd Functional  Fireplaces FireplaceQu GarageType  GarageYrBlt  \
# 0                8        Typ           0         NaN     Attchd       2003.0
# 1                6        Typ           1          TA     Attchd       1976.0
# 2                6        Typ           1          TA     Attchd       2001.0
# 3                7        Typ           1          Gd     Detchd       1998.0
# 4                9        Typ           1          TA     Attchd       2000.0
# ...            ...        ...         ...         ...        ...          ...
# 1455             7        Typ           1          TA     Attchd       1999.0
# 1456             7       Min1           2          TA     Attchd       1978.0
# 1457             9        Typ           2          Gd     Attchd       1941.0
# 1458             5        Typ           0         NaN     Attchd       1950.0
# 1459             6        Typ           0         NaN     Attchd       1965.0
#
#      GarageFinish  GarageCars  GarageArea GarageQual GarageCond PavedDrive  \
# 0             RFn           2         548         TA         TA          Y
# 1             RFn           2         460         TA         TA          Y
# 2             RFn           2         608         TA         TA          Y
# 3             Unf           3         642         TA         TA          Y
# 4             RFn           3         836         TA         TA          Y
# ...           ...         ...         ...        ...        ...        ...
# 1455          RFn           2         460         TA         TA          Y
# 1456          Unf           2         500         TA         TA          Y
# 1457          RFn           1         252         TA         TA          Y
# 1458          Unf           1         240         TA         TA          Y
# 1459          Fin           1         276         TA         TA          Y
#
#       WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  \
# 0              0           61              0          0            0
# 1            298            0              0          0            0
# 2              0           42              0          0            0
# 3              0           35            272          0            0
# 4            192           84              0          0            0
# ...          ...          ...            ...        ...          ...
# 1455           0           40              0          0            0
# 1456         349            0              0          0            0
# 1457           0           60              0          0            0
# 1458         366            0            112          0            0
# 1459         736           68              0          0            0
#
#       PoolArea PoolQC  Fence MiscFeature  MiscVal  MoSold  YrSold SaleType  \
# 0            0    NaN    NaN         NaN        0       2    2008       WD
# 1            0    NaN    NaN         NaN        0       5    2007       WD
# 2            0    NaN    NaN         NaN        0       9    2008       WD
# 3            0    NaN    NaN         NaN        0       2    2006       WD
# 4            0    NaN    NaN         NaN        0      12    2008       WD
# ...        ...    ...    ...         ...      ...     ...     ...      ...
# 1455         0    NaN    NaN         NaN        0       8    2007       WD
# 1456         0    NaN  MnPrv         NaN        0       2    2010       WD
# 1457         0    NaN  GdPrv        Shed     2500       5    2010       WD
# 1458         0    NaN    NaN         NaN        0       4    2010       WD
# 1459         0    NaN    NaN         NaN        0       6    2008       WD
#
#      SaleCondition
# 0           Normal
# 1           Normal
# 2           Normal
# 3          Abnorml
# 4           Normal
# ...            ...
# 1455        Normal
# 1456        Normal
# 1457        Normal
# 1458        Normal
# 1459        Normal
#
# [1460 rows x 80 columns]

# %%
hp_saleprice
# Out:
#       SalePrice
# 0        208500
# 1        181500
# 2        223500
# 3        140000
# 4        250000
# ...         ...
# 1455     175000
# 1456     210000
# 1457     266500
# 1458     142125
# 1459     147500
#
# [1460 rows x 1 columns]

# %%
hp.to_csv('../hp.csv', index=False)

# %%
hp_saleprice.to_csv('../hp_saleprice.csv', index=False)

# %%
hp_saleprice['SalePrice'].hist(bins=range(min(hp_saleprice['SalePrice']), 
                                          max(hp_saleprice['SalePrice']) + 1, 25000),
                               figsize=(20,10))
# Out:
# <AxesSubplot:>

# %%
hp_logsaleprice = pd.DataFrame(np.log(hp_saleprice))
hp_logsaleprice
# Out:
#       SalePrice
# 0     12.247694
# 1     12.109011
# 2     12.317167
# 3     11.849398
# 4     12.429216
# ...         ...
# 1455  12.072541
# 1456  12.254863
# 1457  12.493130
# 1458  11.864462
# 1459  11.901583
#
# [1460 rows x 1 columns]

# %%
hp_logsaleprice.hist(figsize=(20,10))
# Out:
# array([[<AxesSubplot:title={'center':'SalePrice'}>]], dtype=object)

# %%
hp_logsaleprice.to_csv('../hp_logsaleprice.csv', index=False)

# %% [markdown]
# ## General info

# %%
hp.info()

# [LotFrontage, Alley, MasVnrType, MasVnrArea]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 80 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
#  17  OverallQual    1460 non-null   int64
#  18  OverallCond    1460 non-null   int64
#  19  YearBuilt      1460 non-null   int64
#  20  YearRemodAdd   1460 non-null   int64
#  21  RoofStyle      1460 non-null   object
#  22  RoofMatl       1460 non-null   object
#  23  Exterior1st    1460 non-null   object
#  24  Exterior2nd    1460 non-null   object
#  25  MasVnrType     1452 non-null   object
#  26  MasVnrArea     1452 non-null   float64
#  27  ExterQual      1460 non-null   object
#  28  ExterCond      1460 non-null   object
#  29  Foundation     1460 non-null   object
#  30  BsmtQual       1423 non-null   object
#  31  BsmtCond       1423 non-null   object
#  32  BsmtExposure   1422 non-null   object
#  33  BsmtFinType1   1423 non-null   object
#  34  BsmtFinSF1     1460 non-null   int64
#  35  BsmtFinType2   1422 non-null   object
#  36  BsmtFinSF2     1460 non-null   int64
#  37  BsmtUnfSF      1460 non-null   int64
#  38  TotalBsmtSF    1460 non-null   int64
#  39  Heating        1460 non-null   object
#  40  HeatingQC      1460 non-null   object
#  41  CentralAir     1460 non-null   object
#  42  Electrical     1459 non-null   object
#  43  1stFlrSF       1460 non-null   int64
#  44  2ndFlrSF       1460 non-null   int64
#  45  LowQualFinSF   1460 non-null   int64
#  46  GrLivArea      1460 non-null   int64
#  47  BsmtFullBath   1460 non-null   int64
#  48  BsmtHalfBath   1460 non-null   int64
#  49  FullBath       1460 non-null   int64
#  50  HalfBath       1460 non-null   int64
#  51  BedroomAbvGr   1460 non-null   int64
#  52  KitchenAbvGr   1460 non-null   int64
#  53  KitchenQual    1460 non-null   object
#  54  TotRmsAbvGrd   1460 non-null   int64
#  55  Functional     1460 non-null   object
#  56  Fireplaces     1460 non-null   int64
#  57  FireplaceQu    770 non-null    object
#  58  GarageType     1379 non-null   object
#  59  GarageYrBlt    1379 non-null   float64
#  60  GarageFinish   1379 non-null   object
#  61  GarageCars     1460 non-null   int64
#  62  GarageArea     1460 non-null   int64
#  63  GarageQual     1379 non-null   object
#  64  GarageCond     1379 non-null   object
#  65  PavedDrive     1460 non-null   object
#  66  WoodDeckSF     1460 non-null   int64
#  67  OpenPorchSF    1460 non-null   int64
#  68  EnclosedPorch  1460 non-null   int64
#  69  3SsnPorch      1460 non-null   int64
#  70  ScreenPorch    1460 non-null   int64
#  71  PoolArea       1460 non-null   int64
#  72  PoolQC         7 non-null      object
#  73  Fence          281 non-null    object
#  74  MiscFeature    54 non-null     object
#  75  MiscVal        1460 non-null   int64
#  76  MoSold         1460 non-null   int64
#  77  YrSold         1460 non-null   int64
#  78  SaleType       1460 non-null   object
#  79  SaleCondition  1460 non-null   object
# dtypes: float64(3), int64(34), object(43)
# memory usage: 912.6+ KB

# %%
hp.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
#        'GarageCond', 'PavedDrive', 'WoodDeckSF', 'OpenPorchSF',
#        'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'PoolQC',
#        'Fence', 'MiscFeature', 'MiscVal', 'MoSold', 'YrSold', 'SaleType',
#        'SaleCondition'],
#       dtype='object')

# %%
hp.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726
# std       1.112799    30.202904     20.645407   181.066207   456.098091
# min       1.000000  1872.000000   1950.000000     0.000000     0.000000
# 25%       5.000000  1954.000000   1967.000000     0.000000     0.000000
# 50%       5.000000  1973.000000   1994.000000     0.000000   383.500000
# 75%       6.000000  2000.000000   2004.000000   166.000000   712.250000
# max       9.000000  2010.000000   2010.000000  1600.000000  5644.000000
#
#         BsmtFinSF2    BsmtUnfSF  TotalBsmtSF     1stFlrSF     2ndFlrSF  \
# count  1460.000000  1460.000000  1460.000000  1460.000000  1460.000000
# mean     46.549315   567.240411  1057.429452  1162.626712   346.992466
# std     161.319273   441.866955   438.705324   386.587738   436.528436
# min       0.000000     0.000000     0.000000   334.000000     0.000000
# 25%       0.000000   223.000000   795.750000   882.000000     0.000000
# 50%       0.000000   477.500000   991.500000  1087.000000     0.000000
# 75%       0.000000   808.000000  1298.250000  1391.250000   728.000000
# max    1474.000000  2336.000000  6110.000000  4692.000000  2065.000000
#
#        LowQualFinSF    GrLivArea  BsmtFullBath  BsmtHalfBath     FullBath  \
# count   1460.000000  1460.000000   1460.000000   1460.000000  1460.000000
# mean       5.844521  1515.463699      0.425342      0.057534     1.565068
# std       48.623081   525.480383      0.518911      0.238753     0.550916
# min        0.000000   334.000000      0.000000      0.000000     0.000000
# 25%        0.000000  1129.500000      0.000000      0.000000     1.000000
# 50%        0.000000  1464.000000      0.000000      0.000000     2.000000
# 75%        0.000000  1776.750000      1.000000      0.000000     2.000000
# max      572.000000  5642.000000      3.000000      2.000000     3.000000
#
#           HalfBath  BedroomAbvGr  KitchenAbvGr  TotRmsAbvGrd   Fireplaces  \
# count  1460.000000   1460.000000   1460.000000   1460.000000  1460.000000
# mean      0.382877      2.866438      1.046575      6.517808     0.613014
# std       0.502885      0.815778      0.220338      1.625393     0.644666
# min       0.000000      0.000000      0.000000      2.000000     0.000000
# 25%       0.000000      2.000000      1.000000      5.000000     0.000000
# 50%       0.000000      3.000000      1.000000      6.000000     1.000000
# 75%       1.000000      3.000000      1.000000      7.000000     1.000000
# max       2.000000      8.000000      3.000000     14.000000     3.000000
#
#        GarageYrBlt   GarageCars   GarageArea   WoodDeckSF  OpenPorchSF  \
# count  1379.000000  1460.000000  1460.000000  1460.000000  1460.000000
# mean   1978.506164     1.767123   472.980137    94.244521    46.660274
# std      24.689725     0.747315   213.804841   125.338794    66.256028
# min    1900.000000     0.000000     0.000000     0.000000     0.000000
# 25%    1961.000000     1.000000   334.500000     0.000000     0.000000
# 50%    1980.000000     2.000000   480.000000     0.000000    25.000000
# 75%    2002.000000     2.000000   576.000000   168.000000    68.000000
# max    2010.000000     4.000000  1418.000000   857.000000   547.000000
#
#        EnclosedPorch    3SsnPorch  ScreenPorch     PoolArea       MiscVal  \
# count    1460.000000  1460.000000  1460.000000  1460.000000   1460.000000
# mean       21.954110     3.409589    15.060959     2.758904     43.489041
# std        61.119149    29.317331    55.757415    40.177307    496.123024
# min         0.000000     0.000000     0.000000     0.000000      0.000000
# 25%         0.000000     0.000000     0.000000     0.000000      0.000000
# 50%         0.000000     0.000000     0.000000     0.000000      0.000000
# 75%         0.000000     0.000000     0.000000     0.000000      0.000000
# max       552.000000   508.000000   480.000000   738.000000  15500.000000
#
#             MoSold       YrSold
# count  1460.000000  1460.000000
# mean      6.321918  2007.815753
# std       2.703626     1.328095
# min       1.000000  2006.000000
# 25%       5.000000  2007.000000
# 50%       6.000000  2008.000000
# 75%       8.000000  2009.000000
# max      12.000000  2010.000000

# %% [markdown]
# ## Use First 2 Functions from Functions_Sheet.ipynb to Get Columns with Null Values

# %%
# return a list with the names of columns that contain nans

# columns that have dtype=='object' vs not
    # to use with col_obj_list
cols_obj = []
cols_num = []

# columns that have 0 as a value
    # to use with col_num_list_0
cols_0 = []

# columns with NaN values
    # to use with list_nan_col
cols_w_nan_obj = []
cols_w_nan_num = []

# %% [markdown]
# ## Split Column Names into dtype Object or Other

# %%
# columns that have dtype=='object' vs not

cols_obj = []
cols_num = []

# Creates list of column names with dtype=='object' and one where dtype!='object'
col_obj_list(hp, hp.columns, cols_obj, cols_num)

# %%
# columns that have dtype=='object'

cols_obj
# Out:
# ['MSZoning',
#  'Street',
#  'Alley',
#  'LotShape',
#  'LandContour',
#  'Utilities',
#  'LotConfig',
#  'LandSlope',
#  'Neighborhood',
#  'Condition1',
#  'Condition2',
#  'BldgType',
#  'HouseStyle',
#  'RoofStyle',
#  'RoofMatl',
#  'Exterior1st',
#  'Exterior2nd',
#  'MasVnrType',
#  'ExterQual',
#  'ExterCond',
#  'Foundation',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'Heating',
#  'HeatingQC',
#  'CentralAir',
#  'Electrical',
#  'KitchenQual',
#  'Functional',
#  'FireplaceQu',
#  'GarageType',
#  'GarageFinish',
#  'GarageQual',
#  'GarageCond',
#  'PavedDrive',
#  'PoolQC',
#  'Fence',
#  'MiscFeature',
#  'SaleType',
#  'SaleCondition']

# %%
# columns that do NOT have dtype=='object'

cols_num
# Out:
# ['Id',
#  'MSSubClass',
#  'LotFrontage',
#  'LotArea',
#  'OverallQual',
#  'OverallCond',
#  'YearBuilt',
#  'YearRemodAdd',
#  'MasVnrArea',
#  'BsmtFinSF1',
#  'BsmtFinSF2',
#  'BsmtUnfSF',
#  'TotalBsmtSF',
#  '1stFlrSF',
#  '2ndFlrSF',
#  'LowQualFinSF',
#  'GrLivArea',
#  'BsmtFullBath',
#  'BsmtHalfBath',
#  'FullBath',
#  'HalfBath',
#  'BedroomAbvGr',
#  'KitchenAbvGr',
#  'TotRmsAbvGrd',
#  'Fireplaces',
#  'GarageYrBlt',
#  'GarageCars',
#  'GarageArea',
#  'WoodDeckSF',
#  'OpenPorchSF',
#  'EnclosedPorch',
#  '3SsnPorch',
#  'ScreenPorch',
#  'PoolArea',
#  'MiscVal',
#  'MoSold',
#  'YrSold']

# %% [markdown]
# ## Get Columns with Null Values

# %%
# columns with object dtype that have null values

cols_w_nan_obj = []

# Outputs a list of the columns that have null values
nan_col_list(hp, cols_obj, cols_w_nan_obj)
# Out:
# ['Alley',
#  'MasVnrType',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'Electrical',
#  'FireplaceQu',
#  'GarageType',
#  'GarageFinish',
#  'GarageQual',
#  'GarageCond',
#  'PoolQC',
#  'Fence',
#  'MiscFeature']

# %%
# columns with non-object dtype that have null values

cols_w_nan_num = []

# Outputs a list of the columns that have null values
nan_col_list(hp, cols_num, cols_w_nan_num)
# Out:
# ['LotFrontage', 'MasVnrArea', 'GarageYrBlt']

# %%
np.sum(hp[hp['Alley'].isna()]['Alley'])
# Out:
# 0

# %%
np.sum(hp['Alley'].isna())
# Out:
# 1369

# %% [markdown]
# # Explore Null Values of the Columns

# %% [markdown]
# ## Find Unique Values of Columns of Object dtype Excluding NaNs

# %%
data_dict_obj = {}
data_dict_null_obj = {}
cols_nan_unique(hp, cols_w_nan_obj, data_dict_obj, data_dict_null_obj)

# to visualize via dataframes the unique values that exist in the dataset
# to visualize the null count next to those values

data_dict_obj_df = pd.DataFrame.from_dict(data_dict_obj, orient='index').fillna('')
data_dict_null_obj_df = pd.DataFrame(data_dict_null_obj.items())
data_dict_null_obj_df.columns = ['Col_Name', 'Null_Count']
data_dict_null_obj_df = data_dict_null_obj_df.set_index('Col_Name')
data_dict_null_obj_df
# Out:
#               Null_Count
# Col_Name
# Alley               1369
# MasVnrType             8
# BsmtQual              37
# BsmtCond              37
# BsmtExposure          38
# BsmtFinType1          37
# BsmtFinType2          38
# Electrical             1
# FireplaceQu          690
# GarageType            81
# GarageFinish          81
# GarageQual            81
# GarageCond            81
# PoolQC              1453
# Fence               1179
# MiscFeature         1406

# %%
data_dict_obj_df
# Out:
#                     0       1        2        3        4       5
# Alley            Grvl    Pave
# MasVnrType    BrkFace    None    Stone   BrkCmn
# BsmtQual           Gd      TA       Ex       Fa
# BsmtCond           TA      Gd       Fa       Po
# BsmtExposure       No      Gd       Mn       Av
# BsmtFinType1      GLQ     ALQ      Unf      Rec      BLQ     LwQ
# BsmtFinType2      Unf     BLQ      ALQ      Rec      LwQ     GLQ
# Electrical      SBrkr   FuseF    FuseA    FuseP      Mix
# FireplaceQu        TA      Gd       Fa       Ex       Po
# GarageType     Attchd  Detchd  BuiltIn  CarPort  Basment  2Types
# GarageFinish      RFn     Unf      Fin
# GarageQual         TA      Fa       Gd       Ex       Po
# GarageCond         TA      Fa       Gd       Po       Ex
# PoolQC             Ex      Fa       Gd
# Fence           MnPrv    GdWo    GdPrv     MnWw
# MiscFeature      Shed    Gar2     Othr     TenC

# %%
pd.concat([data_dict_obj_df, data_dict_null_obj_df], axis=1)
# Out:
#                     0       1        2        3        4       5  Null_Count
# Alley            Grvl    Pave                                           1369
# MasVnrType    BrkFace    None    Stone   BrkCmn                            8
# BsmtQual           Gd      TA       Ex       Fa                           37
# BsmtCond           TA      Gd       Fa       Po                           37
# BsmtExposure       No      Gd       Mn       Av                           38
# BsmtFinType1      GLQ     ALQ      Unf      Rec      BLQ     LwQ          37
# BsmtFinType2      Unf     BLQ      ALQ      Rec      LwQ     GLQ          38
# Electrical      SBrkr   FuseF    FuseA    FuseP      Mix                   1
# FireplaceQu        TA      Gd       Fa       Ex       Po                 690
# GarageType     Attchd  Detchd  BuiltIn  CarPort  Basment  2Types          81
# GarageFinish      RFn     Unf      Fin                                    81
# GarageQual         TA      Fa       Gd       Ex       Po                  81
# GarageCond         TA      Fa       Gd       Po       Ex                  81
# PoolQC             Ex      Fa       Gd                                  1453
# Fence           MnPrv    GdWo    GdPrv     MnWw                         1179
# MiscFeature      Shed    Gar2     Othr     TenC                         1406

# %%
hp[hp['MasVnrType']=='None']
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 5        6          50       RL         85.0    14115   Pave   NaN      IR1
# 8        9          50       RM         51.0     6120   Pave   NaN      Reg
# 9       10         190       RL         50.0     7420   Pave   NaN      Reg
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1454  1455          20       FV         62.0     7500   Pave  Pave      Reg
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 1            Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 3            Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 5            Lvl    AllPub    Inside       Gtl      Mitchel       Norm
# 8            Lvl    AllPub    Inside       Gtl      OldTown     Artery
# 9            Lvl    AllPub    Corner       Gtl      BrkSide     Artery
# ...          ...       ...       ...       ...          ...        ...
# 1454         Lvl    AllPub    Inside       Gtl      Somerst       Norm
# 1455         Lvl    AllPub    Inside       Gtl      Gilbert       Norm
# 1457         Lvl    AllPub    Inside       Gtl      Crawfor       Norm
# 1458         Lvl    AllPub    Inside       Gtl        NAmes       Norm
# 1459         Lvl    AllPub    Inside       Gtl      Edwards       Norm
#
#      Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 1          Norm     1Fam     1Story            6            8       1976
# 3          Norm     1Fam     2Story            7            5       1915
# 5          Norm     1Fam     1.5Fin            5            5       1993
# 8          Norm     1Fam     1.5Fin            7            5       1931
# 9        Artery   2fmCon     1.5Unf            5            6       1939
# ...         ...      ...        ...          ...          ...        ...
# 1454       Norm     1Fam     1Story            7            5       2004
# 1455       Norm     1Fam     2Story            6            5       1999
# 1457       Norm     1Fam     2Story            7            9       1941
# 1458       Norm     1Fam     1Story            5            6       1950
# 1459       Norm     1Fam     1Story            5            6       1965
#
#       YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 1             1976     Gable  CompShg     MetalSd     MetalSd       None
# 3             1970     Gable  CompShg     Wd Sdng     Wd Shng       None
# 5             1995     Gable  CompShg     VinylSd     VinylSd       None
# 8             1950     Gable  CompShg     BrkFace     Wd Shng       None
# 9             1950     Gable  CompShg     MetalSd     MetalSd       None
# ...            ...       ...      ...         ...         ...        ...
# 1454          2005     Gable  CompShg     VinylSd     VinylSd       None
# 1455          2000     Gable  CompShg     VinylSd     VinylSd       None
# 1457          2006     Gable  CompShg     CemntBd     CmentBd       None
# 1458          1996       Hip  CompShg     MetalSd     MetalSd       None
# 1459          1965     Gable  CompShg     HdBoard     HdBoard       None
#
#       MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond  \
# 1            0.0        TA        TA     CBlock       Gd       TA
# 3            0.0        TA        TA     BrkTil       TA       Gd
# 5            0.0        TA        TA       Wood       Gd       TA
# 8            0.0        TA        TA     BrkTil       TA       TA
# 9            0.0        TA        TA     BrkTil       TA       TA
# ...          ...       ...       ...        ...      ...      ...
# 1454         0.0        Gd        TA      PConc       Gd       TA
# 1455         0.0        TA        TA      PConc       Gd       TA
# 1457         0.0        Ex        Gd      Stone       TA       Gd
# 1458         0.0        TA        TA     CBlock       TA       TA
# 1459         0.0        Gd        TA     CBlock       TA       TA
#
#      BsmtExposure BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  \
# 1              Gd          ALQ         978          Unf           0
# 3              No          ALQ         216          Unf           0
# 5              No          GLQ         732          Unf           0
# 8              No          Unf           0          Unf           0
# 9              No          GLQ         851          Unf           0
# ...           ...          ...         ...          ...         ...
# 1454           No          GLQ         410          Unf           0
# 1455           No          Unf           0          Unf           0
# 1457           No          GLQ         275          Unf           0
# 1458           Mn          GLQ          49          Rec        1029
# 1459           No          BLQ         830          LwQ         290
#
#       BsmtUnfSF  TotalBsmtSF Heating HeatingQC CentralAir Electrical  \
# 1           284         1262    GasA        Ex          Y      SBrkr
# 3           540          756    GasA        Gd          Y      SBrkr
# 5            64          796    GasA        Ex          Y      SBrkr
# 8           952          952    GasA        Gd          Y      FuseF
# 9           140          991    GasA        Ex          Y      SBrkr
# ...         ...          ...     ...       ...        ...        ...
# 1454        811         1221    GasA        Ex          Y      SBrkr
# 1455        953          953    GasA        Ex          Y      SBrkr
# 1457        877         1152    GasA        Ex          Y      SBrkr
# 1458          0         1078    GasA        Gd          Y      FuseA
# 1459        136         1256    GasA        Gd          Y      SBrkr
#
#       1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  BsmtFullBath  BsmtHalfBath  \
# 1         1262         0             0       1262             0             1
# 3          961       756             0       1717             1             0
# 5          796       566             0       1362             1             0
# 8         1022       752             0       1774             0             0
# 9         1077         0             0       1077             1             0
# ...        ...       ...           ...        ...           ...           ...
# 1454      1221         0             0       1221             1             0
# 1455       953       694             0       1647             0             0
# 1457      1188      1152             0       2340             0             0
# 1458      1078         0             0       1078             1             0
# 1459      1256         0             0       1256             1             0
#
#       FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr KitchenQual  \
# 1            2         0             3             1          TA
# 3            1         0             3             1          Gd
# 5            1         1             1             1          TA
# 8            2         0             2             2          TA
# 9            1         0             2             2          TA
# ...        ...       ...           ...           ...         ...
# 1454         2         0             2             1          Gd
# 1455         2         1             3             1          TA
# 1457         2         0             4             1          Gd
# 1458         1         0             2             1          Gd
# 1459         1         1             3             1          TA
#
#       TotRmsAbvGrd Functional  Fireplaces FireplaceQu GarageType  GarageYrBlt  \
# 1                6        Typ           1          TA     Attchd       1976.0
# 3                7        Typ           1          Gd     Detchd       1998.0
# 5                5        Typ           0         NaN     Attchd       1993.0
# 8                8       Min1           2          TA     Detchd       1931.0
# 9                5        Typ           2          TA     Attchd       1939.0
# ...            ...        ...         ...         ...        ...          ...
# 1454             6        Typ           0         NaN     Attchd       2004.0
# 1455             7        Typ           1          TA     Attchd       1999.0
# 1457             9        Typ           2          Gd     Attchd       1941.0
# 1458             5        Typ           0         NaN     Attchd       1950.0
# 1459             6        Typ           0         NaN     Attchd       1965.0
#
#      GarageFinish  GarageCars  GarageArea GarageQual GarageCond PavedDrive  \
# 1             RFn           2         460         TA         TA          Y
# 3             Unf           3         642         TA         TA          Y
# 5             Unf           2         480         TA         TA          Y
# 8             Unf           2         468         Fa         TA          Y
# 9             RFn           1         205         Gd         TA          Y
# ...           ...         ...         ...        ...        ...        ...
# 1454          RFn           2         400         TA         TA          Y
# 1455          RFn           2         460         TA         TA          Y
# 1457          RFn           1         252         TA         TA          Y
# 1458          Unf           1         240         TA         TA          Y
# 1459          Fin           1         276         TA         TA          Y
#
#       WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  \
# 1            298            0              0          0            0
# 3              0           35            272          0            0
# 5             40           30              0        320            0
# 8             90            0            205          0            0
# 9              0            4              0          0            0
# ...          ...          ...            ...        ...          ...
# 1454           0          113              0          0            0
# 1455           0           40              0          0            0
# 1457           0           60              0          0            0
# 1458         366            0            112          0            0
# 1459         736           68              0          0            0
#
#       PoolArea PoolQC  Fence MiscFeature  MiscVal  MoSold  YrSold SaleType  \
# 1            0    NaN    NaN         NaN        0       5    2007       WD
# 3            0    NaN    NaN         NaN        0       2    2006       WD
# 5            0    NaN  MnPrv        Shed      700      10    2009       WD
# 8            0    NaN    NaN         NaN        0       4    2008       WD
# 9            0    NaN    NaN         NaN        0       1    2008       WD
# ...        ...    ...    ...         ...      ...     ...     ...      ...
# 1454         0    NaN    NaN         NaN        0      10    2009       WD
# 1455         0    NaN    NaN         NaN        0       8    2007       WD
# 1457         0    NaN  GdPrv        Shed     2500       5    2010       WD
# 1458         0    NaN    NaN         NaN        0       4    2010       WD
# 1459         0    NaN    NaN         NaN        0       6    2008       WD
#
#      SaleCondition
# 1           Normal
# 3          Abnorml
# 5           Normal
# 8          Abnorml
# 9           Normal
# ...            ...
# 1454        Normal
# 1455        Normal
# 1457        Normal
# 1458        Normal
# 1459        Normal
#
# [864 rows x 80 columns]

# %% [markdown]
# ### Columns with dtype Object that have 'None' but also have NaNs
#
#
# - MasnVnrType

# %% [markdown]
# ### Will use alternative to 'No' or 'None' as those are used in the data:
#
# - Will use 'DNE'

# %% [markdown]
# ## Replace Appropriate Columns' NaNs with 'DNE'

# %% [markdown]
# ### Columns with dtype Object that should NOT have NaNs:

# %%
should_not_have_nan_obj = ['MasVnrType', 'Electrical']

# %% [markdown]
# ### Columns with dtype non-Object that should NOT have NaNs:

# %%
should_not_have_nan_num = ['LotFrontage', 'MasVnrArea']

# %%
obj_DNE_list = [i for i in cols_w_nan_obj if i not in should_not_have_nan_obj]

# %%
num_DNE_list = [i for i in cols_w_nan_num if i not in should_not_have_nan_num]

# %%
nan_col_obj_list_fillna(hp, obj_DNE_list)

# %%
nan_col_obj_list_fillna(hp, num_DNE_list)

# %% [markdown]
# ### Check if There Are Any NaNs Remaining

# %%
cols_w_nan_obj2 = []

nan_col_list(hp, cols_w_nan_obj, cols_w_nan_obj2)
# Out:
# ['MasVnrType', 'Electrical']

# %%
cols_w_nan_num2 = []

nan_col_list(hp, cols_w_nan_num, cols_w_nan_num2)
# Out:
# ['LotFrontage', 'MasVnrArea']

# %%
cols_obj
# Out:
# ['MSZoning',
#  'Street',
#  'Alley',
#  'LotShape',
#  'LandContour',
#  'Utilities',
#  'LotConfig',
#  'LandSlope',
#  'Neighborhood',
#  'Condition1',
#  'Condition2',
#  'BldgType',
#  'HouseStyle',
#  'RoofStyle',
#  'RoofMatl',
#  'Exterior1st',
#  'Exterior2nd',
#  'MasVnrType',
#  'ExterQual',
#  'ExterCond',
#  'Foundation',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'Heating',
#  'HeatingQC',
#  'CentralAir',
#  'Electrical',
#  'KitchenQual',
#  'Functional',
#  'FireplaceQu',
#  'GarageType',
#  'GarageFinish',
#  'GarageQual',
#  'GarageCond',
#  'PavedDrive',
#  'PoolQC',
#  'Fence',
#  'MiscFeature',
#  'SaleType',
#  'SaleCondition']

# %%
hp['Electrical'].unique()
# Out:
# array(['SBrkr', 'FuseF', 'FuseA', 'FuseP', 'Mix', nan], dtype=object)

# %%
hp[hp['Electrical'].isna()]
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1379  1380          80       RL         73.0     9735   Pave   DNE      Reg
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 1379         Lvl    AllPub    Inside       Gtl       Timber       Norm
#
#      Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 1379       Norm     1Fam       SLvl            5            5       2006
#
#       YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 1379          2007     Gable  CompShg     VinylSd     VinylSd       None
#
#       MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond  \
# 1379         0.0        TA        TA      PConc       Gd       TA
#
#      BsmtExposure BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  \
# 1379           No          Unf           0          Unf           0
#
#       BsmtUnfSF  TotalBsmtSF Heating HeatingQC CentralAir Electrical  \
# 1379        384          384    GasA        Gd          Y        NaN
#
#       1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  BsmtFullBath  BsmtHalfBath  \
# 1379       754       640             0       1394             0             0
#
#       FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr KitchenQual  \
# 1379         2         1             3             1          Gd
#
#       TotRmsAbvGrd Functional  Fireplaces FireplaceQu GarageType  GarageYrBlt  \
# 1379             7        Typ           0         DNE    BuiltIn       2007.0
#
#      GarageFinish  GarageCars  GarageArea GarageQual GarageCond PavedDrive  \
# 1379          Fin           2         400         TA         TA          Y
#
#       WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  \
# 1379         100            0              0          0            0
#
#       PoolArea PoolQC Fence MiscFeature  MiscVal  MoSold  YrSold SaleType  \
# 1379         0    DNE   DNE         DNE        0       5    2008       WD
#
#      SaleCondition
# 1379        Normal

# %%
hp['Electrical'].mode()
# Out:
# 0    SBrkr
# dtype: object

# %%
hp['Electrical'].fillna(hp['Electrical'].mode()[0], inplace=True)

# %%
hp[hp['Electrical'].isna()]
# Out:
# Empty DataFrame
# Columns: [Id, MSSubClass, MSZoning, LotFrontage, LotArea, Street, Alley, LotShape, LandContour, Utilities, LotConfig, LandSlope, Neighborhood, Condition1, Condition2, BldgType, HouseStyle, OverallQual, OverallCond, YearBuilt, YearRemodAdd, RoofStyle, RoofMatl, Exterior1st, Exterior2nd, MasVnrType, MasVnrArea, ExterQual, ExterCond, Foundation, BsmtQual, BsmtCond, BsmtExposure, BsmtFinType1, BsmtFinSF1, BsmtFinType2, BsmtFinSF2, BsmtUnfSF, TotalBsmtSF, Heating, HeatingQC, CentralAir, Electrical, 1stFlrSF, 2ndFlrSF, LowQualFinSF, GrLivArea, BsmtFullBath, BsmtHalfBath, FullBath, HalfBath, BedroomAbvGr, KitchenAbvGr, KitchenQual, TotRmsAbvGrd, Functional, Fireplaces, FireplaceQu, GarageType, GarageYrBlt, GarageFinish, GarageCars, GarageArea, GarageQual, GarageCond, PavedDrive, WoodDeckSF, OpenPorchSF, EnclosedPorch, 3SsnPorch, ScreenPorch, PoolArea, PoolQC, Fence, MiscFeature, MiscVal, MoSold, YrSold, SaleType, SaleCondition]
# Index: []

# %% [markdown]
# ## Find Unique Values of Columns of Non-Object dtype Excluding NaNs

# %%
data_dict_num = {}
data_dict_null_num = {}
cols_nan_unique(hp, cols_w_nan_num, data_dict_num, data_dict_null_num)

# data_dict_obj_df = pd.DataFrame.from_dict(data_dict_obj, orient='index').fillna('')
data_dict_null_num_df = pd.DataFrame(data_dict_null_num.items())
data_dict_null_num_df.columns = ['Col_Name', 'Null_Count']
data_dict_null_num_df = data_dict_null_num_df.set_index('Col_Name')
data_dict_null_num_df
# Out:
#              Null_Count
# Col_Name
# LotFrontage         259
# MasVnrArea            8
# GarageYrBlt           0

# %% [markdown]
# # Fill NaNs and like-NaNs

# %% [markdown]
# #### LotFrontage

# %%
# https://scikit-learn.org/stable/modules/generated/sklearn.impute.KNNImputer.html

# %%
np.sum(hp[hp['LotFrontage']==0]['LotFrontage'])
# Out:
# 0.0

# %%
plt.scatter(x=hp['LotFrontage'], y=hp['LotArea'])

# %% [markdown]
# #### MasVnrArea

# %%
np.sum(hp[hp['MasVnrArea']==0]['MasVnrArea'])
# Out:
# 0.0

# %%
# safer to assume that there is none (0)

hp['MasVnrArea'].hist(bins=30, figsize=(20,10))
# Out:
# <AxesSubplot:>

# %%
np.sum(hp['MasVnrArea'].isna())
# Out:
# 8

# %%
hp.loc[hp.MasVnrArea.isna(), 'MasVnrArea'] = 0
hp[hp['MasVnrArea'].isna()]
# Out:
# Empty DataFrame
# Columns: [Id, MSSubClass, MSZoning, LotFrontage, LotArea, Street, Alley, LotShape, LandContour, Utilities, LotConfig, LandSlope, Neighborhood, Condition1, Condition2, BldgType, HouseStyle, OverallQual, OverallCond, YearBuilt, YearRemodAdd, RoofStyle, RoofMatl, Exterior1st, Exterior2nd, MasVnrType, MasVnrArea, ExterQual, ExterCond, Foundation, BsmtQual, BsmtCond, BsmtExposure, BsmtFinType1, BsmtFinSF1, BsmtFinType2, BsmtFinSF2, BsmtUnfSF, TotalBsmtSF, Heating, HeatingQC, CentralAir, Electrical, 1stFlrSF, 2ndFlrSF, LowQualFinSF, GrLivArea, BsmtFullBath, BsmtHalfBath, FullBath, HalfBath, BedroomAbvGr, KitchenAbvGr, KitchenQual, TotRmsAbvGrd, Functional, Fireplaces, FireplaceQu, GarageType, GarageYrBlt, GarageFinish, GarageCars, GarageArea, GarageQual, GarageCond, PavedDrive, WoodDeckSF, OpenPorchSF, EnclosedPorch, 3SsnPorch, ScreenPorch, PoolArea, PoolQC, Fence, MiscFeature, MiscVal, MoSold, YrSold, SaleType, SaleCondition]
# Index: []

# %%
np.sum(hp['MasVnrArea'].isna())
# Out:
# 0

# %% [markdown]
# ### Check MasVnrArea for any NaNs

# %%
np.sum(hp['MasVnrType'].isna())
# Out:
# 8

# %% [markdown]
# #### Cross-Check MasVnrType and MasVnrArea

# %%
hp[hp['MasVnrType'].isna()][['MasVnrType', 'MasVnrArea']]
# Out:
#      MasVnrType  MasVnrArea
# 234         NaN         0.0
# 529         NaN         0.0
# 650         NaN         0.0
# 936         NaN         0.0
# 973         NaN         0.0
# 977         NaN         0.0
# 1243        NaN         0.0
# 1278        NaN         0.0

# %%
hp.loc[(hp.MasVnrType.isna()) & (hp.MasVnrArea==0), 'MasVnrType']='None'

# %%
hp[hp['MasVnrType'].isna()][['MasVnrType', 'MasVnrArea']]
# Out:
# Empty DataFrame
# Columns: [MasVnrType, MasVnrArea]
# Index: []

# %% [markdown]
# #### Check for discrepancies between Type and Area

# %%
# Will use mode of MasVnrType if MasVnrArea is > 1

hp[(hp['MasVnrType']=='None') & (hp['MasVnrArea']!=0)][['MasVnrType', 'MasVnrArea']]
# Out:
#      MasVnrType  MasVnrArea
# 624        None       288.0
# 773        None         1.0
# 1230       None         1.0
# 1300       None       344.0
# 1334       None       312.0

# %%
# Will assume MasVnrArea of 1 are actually 0 based on previous cell

hp.loc[hp.MasVnrArea==1, 'MasVnrArea'] = 0

# %%
hp[(hp['MasVnrType']=='None') & (hp['MasVnrArea']!=0)][['MasVnrType', 'MasVnrArea']]
# Out:
#      MasVnrType  MasVnrArea
# 624        None       288.0
# 1300       None       344.0
# 1334       None       312.0

# %%
hp['MasVnrType'].value_counts()
# Out:
# None       872
# BrkFace    445
# Stone      128
# BrkCmn      15
# Name: MasVnrType, dtype: int64

# %%
hp[hp['MasVnrType']=='BrkFace']['MasVnrArea'].hist(bins=40, figsize=(20,10))
# Out:
# <AxesSubplot:>

# %%
hp[hp['MasVnrType']=='Stone']['MasVnrArea'].hist(bins=30, figsize=(20,10))
# Out:
# <AxesSubplot:>

# %%
hp[hp['MasVnrType']=='BrkCmn']['MasVnrArea'].hist(bins=15, figsize=(20,10))
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Based on the Graphs above, we can see that BrkFace has the highest count

# %%
# ['MasVnrType'] should = the mode of the ['MasVnrType'] that is NOT None

from collections import Counter

masvnrtype_mode = [x[0] for x in Counter(list(hp['MasVnrType'])).most_common()]
    # outputs something that looks like: ['None', 'BrkFace', 'Stone', 'BrkCmn']

if masvnrtype_mode[0]=='None':
    hp.loc[(hp.MasVnrArea > 1) & (hp.MasVnrType == 'None'), 'MasVnrType'] = masvnrtype_mode[1]
else:
    hp.loc[(hp.MasVnrArea > 1) & (hp.MasVnrType == 'None'), 'MasVnrType'] = masvnrtype_mode[0]

# %%
hp[(hp['MasVnrType']=='None') & (hp['MasVnrArea']!=0)][['MasVnrType', 'MasVnrArea']]

# we have successfully converted MasVnrType of 'None' to the most common VnrType that is NOT 'None' as long as the
# MasVnrArea is greater than 0
# Out:
# Empty DataFrame
# Columns: [MasVnrType, MasVnrArea]
# Index: []

# %%
hp.loc[624, ['MasVnrType', 'MasVnrArea']]
# Out:
# MasVnrType    BrkFace
# MasVnrArea      288.0
# Name: 624, dtype: object

# %%
hp.loc[1300, ['MasVnrType', 'MasVnrArea']]
# Out:
# MasVnrType    BrkFace
# MasVnrArea      344.0
# Name: 1300, dtype: object

# %%
hp.loc[1334, ['MasVnrType', 'MasVnrArea']]
# Out:
# MasVnrType    BrkFace
# MasVnrArea      312.0
# Name: 1334, dtype: object

# %%
hp['MasVnrType'].unique()
# Out:
# array(['BrkFace', 'None', 'Stone', 'BrkCmn'], dtype=object)

# %%
# Here we see that there are 2 times when MasVnrArea is 0, there is a Type recorded

# maybe use mean or mode of MasVnrArea for each of the MasVnrType?
    # Maybe use KNN?


hp[(hp['MasVnrType']!='None') & (hp['MasVnrArea']==0)][['MasVnrType', 'MasVnrArea']]
# Out:
#      MasVnrType  MasVnrArea
# 688     BrkFace         0.0
# 1241      Stone         0.0

# %%
print(hp.loc[hp['MasVnrType']=='BrkFace', 'MasVnrArea'].mean())
print(hp.loc[hp['MasVnrType']=='BrkFace', 'MasVnrArea'].median())
print(hp.loc[hp['MasVnrType']=='BrkFace', 'MasVnrArea'].mode())
# Out:
# 259.38169642857144
# 203.5
# 0    120.0
# 1    180.0
# dtype: float64

# %% [markdown]
# #### Replace values in MasVnrArea that have a Type, but are == 0
#
# - use Mode

# %%
list(hp[(hp['MasVnrType']!='None') & (hp['MasVnrArea']==0)]['MasVnrType'])
# Out:
# ['BrkFace', 'Stone']

# %%
mvt_list = set(list(hp[(hp['MasVnrType']!='None') & (hp['MasVnrArea']==0)]['MasVnrType']))

fill_masvnrtype(hp, mvt_list)
# Out:
# [0, 1]
# 150.0

# %%
print(hp.loc[hp['MasVnrType']=='BrkFace', 'MasVnrArea'].mean())
print(hp.loc[hp['MasVnrType']=='BrkFace', 'MasVnrArea'].median())
print(hp.loc[hp['MasVnrType']=='BrkFace', 'MasVnrArea'].mode())
# Out:
# 259.71651785714283
# 203.5
# 0    120.0
# 1    180.0
# dtype: float64

# %%
print(hp.loc[hp['MasVnrType']=='Stone', 'MasVnrArea'].mean())
print(hp.loc[hp['MasVnrType']=='Stone', 'MasVnrArea'].median())
print(hp.loc[hp['MasVnrType']=='Stone', 'MasVnrArea'].mode())
# Out:
# 240.234375
# 206.5
# 0     50.0
# 1     72.0
# 2    100.0
# 3    106.0
# 4    186.0
# 5    200.0
# dtype: float64

# %%
hp[(hp['MasVnrType'].isna()) & (hp['MasVnrArea']!=0)][['MasVnrType', 'MasVnrArea']]
# Out:
# Empty DataFrame
# Columns: [MasVnrType, MasVnrArea]
# Index: []

# %%
hp[(hp['MasVnrType']!='None') & (hp['MasVnrArea'].isna())][['MasVnrType', 'MasVnrArea']]
# Out:
# Empty DataFrame
# Columns: [MasVnrType, MasVnrArea]
# Index: []

# %%
np.sum(hp[hp['GarageYrBlt']==0]['GarageYrBlt'])
# Out:
# 0.0

# %% [markdown]
# ## Replace null in GarageYrBlt and change to 'YrSold'

# %%
hp[hp['GarageYrBlt']==0]
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 39      40          90       RL         65.0     6040   Pave   DNE      Reg
# 48      49         190       RM         33.0     4456   Pave   DNE      Reg
# 78      79          90       RL         72.0    10778   Pave   DNE      Reg
# 88      89          50  C (all)        105.0     8470   Pave   DNE      IR1
# 89      90          20       RL         60.0     8070   Pave   DNE      Reg
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1349  1350          70       RM         50.0     5250   Pave  Pave      Reg
# 1407  1408          20       RL          NaN     8780   Pave   DNE      IR1
# 1449  1450         180       RM         21.0     1533   Pave   DNE      Reg
# 1450  1451          90       RL         60.0     9000   Pave   DNE      Reg
# 1453  1454          20       RL         90.0    17217   Pave   DNE      Reg
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 39           Lvl    AllPub    Inside       Gtl      Edwards       Norm
# 48           Lvl    AllPub    Inside       Gtl      OldTown       Norm
# 78           Lvl    AllPub    Inside       Gtl       Sawyer       Norm
# 88           Lvl    AllPub    Corner       Gtl       IDOTRR      Feedr
# 89           Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# ...          ...       ...       ...       ...          ...        ...
# 1349         Lvl    AllPub    Inside       Gtl      OldTown       Norm
# 1407         Lvl    AllPub    Corner       Gtl      Mitchel       Norm
# 1449         Lvl    AllPub    Inside       Gtl      MeadowV       Norm
# 1450         Lvl    AllPub       FR2       Gtl        NAmes       Norm
# 1453         Lvl    AllPub    Inside       Gtl      Mitchel       Norm
#
#      Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 39         Norm   Duplex     1Story            4            5       1955
# 48         Norm   2fmCon     2Story            4            5       1920
# 78         Norm   Duplex     1Story            4            5       1968
# 88        Feedr     1Fam     1.5Fin            3            2       1915
# 89         Norm     1Fam     1Story            4            5       1994
# ...         ...      ...        ...          ...          ...        ...
# 1349       Norm     1Fam     2Story            8            5       1872
# 1407       Norm     1Fam     1Story            5            5       1985
# 1449       Norm    Twnhs     SFoyer            5            7       1970
# 1450       Norm   Duplex     2Story            5            5       1974
# 1453       Norm     1Fam     1Story            5            5       2006
#
#       YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 39            1955     Gable  CompShg     AsbShng     Plywood       None
# 48            2008     Gable  CompShg     MetalSd     MetalSd       None
# 78            1968       Hip  CompShg     HdBoard     HdBoard       None
# 88            1982       Hip  CompShg     Plywood     Plywood       None
# 89            1995     Gable  CompShg     VinylSd     VinylSd       None
# ...            ...       ...      ...         ...         ...        ...
# 1349          1987     Gable  CompShg     MetalSd     MetalSd       None
# 1407          1985     Gable  CompShg     HdBoard     Plywood       None
# 1449          1970     Gable  CompShg     CemntBd     CmentBd       None
# 1450          1974     Gable  CompShg     VinylSd     VinylSd       None
# 1453          2006     Gable  CompShg     VinylSd     VinylSd       None
#
#       MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond  \
# 39           0.0        TA        TA      PConc      DNE      DNE
# 48           0.0        TA        TA     BrkTil       TA       TA
# 78           0.0        TA        TA     CBlock       TA       TA
# 88           0.0        Fa        Fa     CBlock       TA       Fa
# 89           0.0        TA        TA      PConc       Gd       TA
# ...          ...       ...       ...        ...      ...      ...
# 1349         0.0        TA        Gd     BrkTil       TA       Fa
# 1407         0.0        TA        TA     CBlock       TA       TA
# 1449         0.0        TA        TA     CBlock       Gd       TA
# 1450         0.0        TA        TA     CBlock       Gd       TA
# 1453         0.0        TA        TA      PConc       Gd       TA
#
#      BsmtExposure BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  \
# 39            DNE          DNE           0          DNE           0
# 48             No          Unf           0          Unf           0
# 78             No          Unf           0          Unf           0
# 88             No          Unf           0          Unf           0
# 89             No          GLQ         588          Unf           0
# ...           ...          ...         ...          ...         ...
# 1349           No          LwQ         259          Unf           0
# 1407           No          ALQ         625          Unf           0
# 1449           Av          GLQ         553          Unf           0
# 1450           No          Unf           0          Unf           0
# 1453           No          Unf           0          Unf           0
#
#       BsmtUnfSF  TotalBsmtSF Heating HeatingQC CentralAir Electrical  \
# 39            0            0    GasA        TA          N      FuseP
# 48          736          736    GasA        Gd          Y      SBrkr
# 78         1768         1768    GasA        TA          N      SBrkr
# 88         1013         1013    GasA        TA          N      SBrkr
# 89          402          990    GasA        Ex          Y      SBrkr
# ...         ...          ...     ...       ...        ...        ...
# 1349        425          684    OthW        Fa          N      SBrkr
# 1407        208          833    GasA        Ex          Y      SBrkr
# 1449         77          630    GasA        Ex          Y      SBrkr
# 1450        896          896    GasA        TA          Y      SBrkr
# 1453       1140         1140    GasA        Ex          Y      SBrkr
#
#       1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  BsmtFullBath  BsmtHalfBath  \
# 39        1152         0             0       1152             0             0
# 48         736       716             0       1452             0             0
# 78        1768         0             0       1768             0             0
# 88        1013         0           513       1526             0             0
# 89         990         0             0        990             1             0
# ...        ...       ...           ...        ...           ...           ...
# 1349       938      1215           205       2358             0             0
# 1407       833         0             0        833             1             0
# 1449       630         0             0        630             1             0
# 1450       896       896             0       1792             0             0
# 1453      1140         0             0       1140             0             0
#
#       FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr KitchenQual  \
# 39           2         0             2             2          Fa
# 48           2         0             2             3          TA
# 78           2         0             4             2          TA
# 88           1         0             2             1          Fa
# 89           1         0             3             1          TA
# ...        ...       ...           ...           ...         ...
# 1349         2         0             4             1          TA
# 1407         1         0             3             1          TA
# 1449         1         0             1             1          Ex
# 1450         2         2             4             2          TA
# 1453         1         0             3             1          TA
#
#       TotRmsAbvGrd Functional  Fireplaces FireplaceQu GarageType  GarageYrBlt  \
# 39               6        Typ           0         DNE        DNE          0.0
# 48               8        Typ           0         DNE        DNE          0.0
# 78               8        Typ           0         DNE        DNE          0.0
# 88               6        Typ           0         DNE        DNE          0.0
# 89               5        Typ           0         DNE        DNE          0.0
# ...            ...        ...         ...         ...        ...          ...
# 1349             8        Typ           0         DNE        DNE          0.0
# 1407             5        Typ           0         DNE        DNE          0.0
# 1449             3        Typ           0         DNE        DNE          0.0
# 1450             8        Typ           0         DNE        DNE          0.0
# 1453             6        Typ           0         DNE        DNE          0.0
#
#      GarageFinish  GarageCars  GarageArea GarageQual GarageCond PavedDrive  \
# 39            DNE           0           0        DNE        DNE          N
# 48            DNE           0           0        DNE        DNE          N
# 78            DNE           0           0        DNE        DNE          Y
# 88            DNE           0           0        DNE        DNE          N
# 89            DNE           0           0        DNE        DNE          Y
# ...           ...         ...         ...        ...        ...        ...
# 1349          DNE           0           0        DNE        DNE          Y
# 1407          DNE           0           0        DNE        DNE          Y
# 1449          DNE           0           0        DNE        DNE          Y
# 1450          DNE           0           0        DNE        DNE          Y
# 1453          DNE           0           0        DNE        DNE          Y
#
#       WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  \
# 39             0            0              0          0            0
# 48             0            0            102          0            0
# 78             0            0              0          0            0
# 88             0            0            156          0            0
# 89             0            0              0          0            0
# ...          ...          ...            ...        ...          ...
# 1349           0           54             20          0            0
# 1407           0            0              0          0            0
# 1449           0            0              0          0            0
# 1450          32           45              0          0            0
# 1453          36           56              0          0            0
#
#       PoolArea PoolQC  Fence MiscFeature  MiscVal  MoSold  YrSold SaleType  \
# 39           0    DNE    DNE         DNE        0       6    2008       WD
# 48           0    DNE    DNE         DNE        0       6    2009      New
# 78           0    DNE    DNE         DNE        0       4    2010       WD
# 88           0    DNE  MnPrv         DNE        0      10    2009    ConLD
# 89           0    DNE    DNE         DNE        0       8    2007       WD
# ...        ...    ...    ...         ...      ...     ...     ...      ...
# 1349         0    DNE    DNE         DNE        0      12    2008       WD
# 1407         0    DNE  MnPrv         DNE        0       3    2009       WD
# 1449         0    DNE    DNE         DNE        0       8    2006       WD
# 1450         0    DNE    DNE         DNE        0       9    2009       WD
# 1453         0    DNE    DNE         DNE        0       7    2006       WD
#
#      SaleCondition
# 39         AdjLand
# 48         Partial
# 78          Normal
# 88         Abnorml
# 89          Normal
# ...            ...
# 1349        Normal
# 1407        Normal
# 1449       Abnorml
# 1450        Normal
# 1453       Abnorml
#
# [81 rows x 80 columns]

# %%
hp[hp['YearBuilt'].isna()]
# Out:
# Empty DataFrame
# Columns: [Id, MSSubClass, MSZoning, LotFrontage, LotArea, Street, Alley, LotShape, LandContour, Utilities, LotConfig, LandSlope, Neighborhood, Condition1, Condition2, BldgType, HouseStyle, OverallQual, OverallCond, YearBuilt, YearRemodAdd, RoofStyle, RoofMatl, Exterior1st, Exterior2nd, MasVnrType, MasVnrArea, ExterQual, ExterCond, Foundation, BsmtQual, BsmtCond, BsmtExposure, BsmtFinType1, BsmtFinSF1, BsmtFinType2, BsmtFinSF2, BsmtUnfSF, TotalBsmtSF, Heating, HeatingQC, CentralAir, Electrical, 1stFlrSF, 2ndFlrSF, LowQualFinSF, GrLivArea, BsmtFullBath, BsmtHalfBath, FullBath, HalfBath, BedroomAbvGr, KitchenAbvGr, KitchenQual, TotRmsAbvGrd, Functional, Fireplaces, FireplaceQu, GarageType, GarageYrBlt, GarageFinish, GarageCars, GarageArea, GarageQual, GarageCond, PavedDrive, WoodDeckSF, OpenPorchSF, EnclosedPorch, 3SsnPorch, ScreenPorch, PoolArea, PoolQC, Fence, MiscFeature, MiscVal, MoSold, YrSold, SaleType, SaleCondition]
# Index: []

# %%
hp[hp['YearRemodAdd'].isna()]
# Out:
# Empty DataFrame
# Columns: [Id, MSSubClass, MSZoning, LotFrontage, LotArea, Street, Alley, LotShape, LandContour, Utilities, LotConfig, LandSlope, Neighborhood, Condition1, Condition2, BldgType, HouseStyle, OverallQual, OverallCond, YearBuilt, YearRemodAdd, RoofStyle, RoofMatl, Exterior1st, Exterior2nd, MasVnrType, MasVnrArea, ExterQual, ExterCond, Foundation, BsmtQual, BsmtCond, BsmtExposure, BsmtFinType1, BsmtFinSF1, BsmtFinType2, BsmtFinSF2, BsmtUnfSF, TotalBsmtSF, Heating, HeatingQC, CentralAir, Electrical, 1stFlrSF, 2ndFlrSF, LowQualFinSF, GrLivArea, BsmtFullBath, BsmtHalfBath, FullBath, HalfBath, BedroomAbvGr, KitchenAbvGr, KitchenQual, TotRmsAbvGrd, Functional, Fireplaces, FireplaceQu, GarageType, GarageYrBlt, GarageFinish, GarageCars, GarageArea, GarageQual, GarageCond, PavedDrive, WoodDeckSF, OpenPorchSF, EnclosedPorch, 3SsnPorch, ScreenPorch, PoolArea, PoolQC, Fence, MiscFeature, MiscVal, MoSold, YrSold, SaleType, SaleCondition]
# Index: []

# %%
hp[hp.YearBuilt>hp.YearRemodAdd]
# Out:
# Empty DataFrame
# Columns: [Id, MSSubClass, MSZoning, LotFrontage, LotArea, Street, Alley, LotShape, LandContour, Utilities, LotConfig, LandSlope, Neighborhood, Condition1, Condition2, BldgType, HouseStyle, OverallQual, OverallCond, YearBuilt, YearRemodAdd, RoofStyle, RoofMatl, Exterior1st, Exterior2nd, MasVnrType, MasVnrArea, ExterQual, ExterCond, Foundation, BsmtQual, BsmtCond, BsmtExposure, BsmtFinType1, BsmtFinSF1, BsmtFinType2, BsmtFinSF2, BsmtUnfSF, TotalBsmtSF, Heating, HeatingQC, CentralAir, Electrical, 1stFlrSF, 2ndFlrSF, LowQualFinSF, GrLivArea, BsmtFullBath, BsmtHalfBath, FullBath, HalfBath, BedroomAbvGr, KitchenAbvGr, KitchenQual, TotRmsAbvGrd, Functional, Fireplaces, FireplaceQu, GarageType, GarageYrBlt, GarageFinish, GarageCars, GarageArea, GarageQual, GarageCond, PavedDrive, WoodDeckSF, OpenPorchSF, EnclosedPorch, 3SsnPorch, ScreenPorch, PoolArea, PoolQC, Fence, MiscFeature, MiscVal, MoSold, YrSold, SaleType, SaleCondition]
# Index: []

# %%
hp[hp.YearBuilt<hp.YearRemodAdd]
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 2        3          60       RL         68.0    11250   Pave   DNE      IR1
# 3        4          70       RL         60.0     9550   Pave   DNE      IR1
# 5        6          50       RL         85.0    14115   Pave   DNE      IR1
# 6        7          20       RL         75.0    10084   Pave   DNE      Reg
# 8        9          50       RM         51.0     6120   Pave   DNE      Reg
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1454  1455          20       FV         62.0     7500   Pave  Pave      Reg
# 1455  1456          60       RL         62.0     7917   Pave   DNE      Reg
# 1456  1457          20       RL         85.0    13175   Pave   DNE      Reg
# 1457  1458          70       RL         66.0     9042   Pave   DNE      Reg
# 1458  1459          20       RL         68.0     9717   Pave   DNE      Reg
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 2            Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3            Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 5            Lvl    AllPub    Inside       Gtl      Mitchel       Norm
# 6            Lvl    AllPub    Inside       Gtl      Somerst       Norm
# 8            Lvl    AllPub    Inside       Gtl      OldTown     Artery
# ...          ...       ...       ...       ...          ...        ...
# 1454         Lvl    AllPub    Inside       Gtl      Somerst       Norm
# 1455         Lvl    AllPub    Inside       Gtl      Gilbert       Norm
# 1456         Lvl    AllPub    Inside       Gtl       NWAmes       Norm
# 1457         Lvl    AllPub    Inside       Gtl      Crawfor       Norm
# 1458         Lvl    AllPub    Inside       Gtl        NAmes       Norm
#
#      Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 2          Norm     1Fam     2Story            7            5       2001
# 3          Norm     1Fam     2Story            7            5       1915
# 5          Norm     1Fam     1.5Fin            5            5       1993
# 6          Norm     1Fam     1Story            8            5       2004
# 8          Norm     1Fam     1.5Fin            7            5       1931
# ...         ...      ...        ...          ...          ...        ...
# 1454       Norm     1Fam     1Story            7            5       2004
# 1455       Norm     1Fam     2Story            6            5       1999
# 1456       Norm     1Fam     1Story            6            6       1978
# 1457       Norm     1Fam     2Story            7            9       1941
# 1458       Norm     1Fam     1Story            5            6       1950
#
#       YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 2             2002     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 3             1970     Gable  CompShg     Wd Sdng     Wd Shng       None
# 5             1995     Gable  CompShg     VinylSd     VinylSd       None
# 6             2005     Gable  CompShg     VinylSd     VinylSd      Stone
# 8             1950     Gable  CompShg     BrkFace     Wd Shng       None
# ...            ...       ...      ...         ...         ...        ...
# 1454          2005     Gable  CompShg     VinylSd     VinylSd       None
# 1455          2000     Gable  CompShg     VinylSd     VinylSd       None
# 1456          1988     Gable  CompShg     Plywood     Plywood      Stone
# 1457          2006     Gable  CompShg     CemntBd     CmentBd       None
# 1458          1996       Hip  CompShg     MetalSd     MetalSd       None
#
#       MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond  \
# 2          162.0        Gd        TA      PConc       Gd       TA
# 3            0.0        TA        TA     BrkTil       TA       Gd
# 5            0.0        TA        TA       Wood       Gd       TA
# 6          186.0        Gd        TA      PConc       Ex       TA
# 8            0.0        TA        TA     BrkTil       TA       TA
# ...          ...       ...       ...        ...      ...      ...
# 1454         0.0        Gd        TA      PConc       Gd       TA
# 1455         0.0        TA        TA      PConc       Gd       TA
# 1456       119.0        TA        TA     CBlock       Gd       TA
# 1457         0.0        Ex        Gd      Stone       TA       Gd
# 1458         0.0        TA        TA     CBlock       TA       TA
#
#      BsmtExposure BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  \
# 2              Mn          GLQ         486          Unf           0
# 3              No          ALQ         216          Unf           0
# 5              No          GLQ         732          Unf           0
# 6              Av          GLQ        1369          Unf           0
# 8              No          Unf           0          Unf           0
# ...           ...          ...         ...          ...         ...
# 1454           No          GLQ         410          Unf           0
# 1455           No          Unf           0          Unf           0
# 1456           No          ALQ         790          Rec         163
# 1457           No          GLQ         275          Unf           0
# 1458           Mn          GLQ          49          Rec        1029
#
#       BsmtUnfSF  TotalBsmtSF Heating HeatingQC CentralAir Electrical  \
# 2           434          920    GasA        Ex          Y      SBrkr
# 3           540          756    GasA        Gd          Y      SBrkr
# 5            64          796    GasA        Ex          Y      SBrkr
# 6           317         1686    GasA        Ex          Y      SBrkr
# 8           952          952    GasA        Gd          Y      FuseF
# ...         ...          ...     ...       ...        ...        ...
# 1454        811         1221    GasA        Ex          Y      SBrkr
# 1455        953          953    GasA        Ex          Y      SBrkr
# 1456        589         1542    GasA        TA          Y      SBrkr
# 1457        877         1152    GasA        Ex          Y      SBrkr
# 1458          0         1078    GasA        Gd          Y      FuseA
#
#       1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  BsmtFullBath  BsmtHalfBath  \
# 2          920       866             0       1786             1             0
# 3          961       756             0       1717             1             0
# 5          796       566             0       1362             1             0
# 6         1694         0             0       1694             1             0
# 8         1022       752             0       1774             0             0
# ...        ...       ...           ...        ...           ...           ...
# 1454      1221         0             0       1221             1             0
# 1455       953       694             0       1647             0             0
# 1456      2073         0             0       2073             1             0
# 1457      1188      1152             0       2340             0             0
# 1458      1078         0             0       1078             1             0
#
#       FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr KitchenQual  \
# 2            2         1             3             1          Gd
# 3            1         0             3             1          Gd
# 5            1         1             1             1          TA
# 6            2         0             3             1          Gd
# 8            2         0             2             2          TA
# ...        ...       ...           ...           ...         ...
# 1454         2         0             2             1          Gd
# 1455         2         1             3             1          TA
# 1456         2         0             3             1          TA
# 1457         2         0             4             1          Gd
# 1458         1         0             2             1          Gd
#
#       TotRmsAbvGrd Functional  Fireplaces FireplaceQu GarageType  GarageYrBlt  \
# 2                6        Typ           1          TA     Attchd       2001.0
# 3                7        Typ           1          Gd     Detchd       1998.0
# 5                5        Typ           0         DNE     Attchd       1993.0
# 6                7        Typ           1          Gd     Attchd       2004.0
# 8                8       Min1           2          TA     Detchd       1931.0
# ...            ...        ...         ...         ...        ...          ...
# 1454             6        Typ           0         DNE     Attchd       2004.0
# 1455             7        Typ           1          TA     Attchd       1999.0
# 1456             7       Min1           2          TA     Attchd       1978.0
# 1457             9        Typ           2          Gd     Attchd       1941.0
# 1458             5        Typ           0         DNE     Attchd       1950.0
#
#      GarageFinish  GarageCars  GarageArea GarageQual GarageCond PavedDrive  \
# 2             RFn           2         608         TA         TA          Y
# 3             Unf           3         642         TA         TA          Y
# 5             Unf           2         480         TA         TA          Y
# 6             RFn           2         636         TA         TA          Y
# 8             Unf           2         468         Fa         TA          Y
# ...           ...         ...         ...        ...        ...        ...
# 1454          RFn           2         400         TA         TA          Y
# 1455          RFn           2         460         TA         TA          Y
# 1456          Unf           2         500         TA         TA          Y
# 1457          RFn           1         252         TA         TA          Y
# 1458          Unf           1         240         TA         TA          Y
#
#       WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  \
# 2              0           42              0          0            0
# 3              0           35            272          0            0
# 5             40           30              0        320            0
# 6            255           57              0          0            0
# 8             90            0            205          0            0
# ...          ...          ...            ...        ...          ...
# 1454           0          113              0          0            0
# 1455           0           40              0          0            0
# 1456         349            0              0          0            0
# 1457           0           60              0          0            0
# 1458         366            0            112          0            0
#
#       PoolArea PoolQC  Fence MiscFeature  MiscVal  MoSold  YrSold SaleType  \
# 2            0    DNE    DNE         DNE        0       9    2008       WD
# 3            0    DNE    DNE         DNE        0       2    2006       WD
# 5            0    DNE  MnPrv        Shed      700      10    2009       WD
# 6            0    DNE    DNE         DNE        0       8    2007       WD
# 8            0    DNE    DNE         DNE        0       4    2008       WD
# ...        ...    ...    ...         ...      ...     ...     ...      ...
# 1454         0    DNE    DNE         DNE        0      10    2009       WD
# 1455         0    DNE    DNE         DNE        0       8    2007       WD
# 1456         0    DNE  MnPrv         DNE        0       2    2010       WD
# 1457         0    DNE  GdPrv        Shed     2500       5    2010       WD
# 1458         0    DNE    DNE         DNE        0       4    2010       WD
#
#      SaleCondition
# 2           Normal
# 3          Abnorml
# 5           Normal
# 6           Normal
# 8          Abnorml
# ...            ...
# 1454        Normal
# 1455        Normal
# 1456        Normal
# 1457        Normal
# 1458        Normal
#
# [696 rows x 80 columns]

# %%
hp[hp.YearBuilt==hp.YearRemodAdd]
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   DNE      Reg
# 1        2          20       RL         80.0     9600   Pave   DNE      Reg
# 4        5          60       RL         84.0    14260   Pave   DNE      IR1
# 7        8          60       RL          NaN    10382   Pave   DNE      IR1
# 10      11          20       RL         70.0    11200   Pave   DNE      Reg
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1449  1450         180       RM         21.0     1533   Pave   DNE      Reg
# 1450  1451          90       RL         60.0     9000   Pave   DNE      Reg
# 1452  1453         180       RM         35.0     3675   Pave   DNE      Reg
# 1453  1454          20       RL         90.0    17217   Pave   DNE      Reg
# 1459  1460          20       RL         75.0     9937   Pave   DNE      Reg
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0            Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1            Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 4            Lvl    AllPub       FR2       Gtl      NoRidge       Norm
# 7            Lvl    AllPub    Corner       Gtl       NWAmes       PosN
# 10           Lvl    AllPub    Inside       Gtl       Sawyer       Norm
# ...          ...       ...       ...       ...          ...        ...
# 1449         Lvl    AllPub    Inside       Gtl      MeadowV       Norm
# 1450         Lvl    AllPub       FR2       Gtl        NAmes       Norm
# 1452         Lvl    AllPub    Inside       Gtl      Edwards       Norm
# 1453         Lvl    AllPub    Inside       Gtl      Mitchel       Norm
# 1459         Lvl    AllPub    Inside       Gtl      Edwards       Norm
#
#      Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 0          Norm     1Fam     2Story            7            5       2003
# 1          Norm     1Fam     1Story            6            8       1976
# 4          Norm     1Fam     2Story            8            5       2000
# 7          Norm     1Fam     2Story            7            6       1973
# 10         Norm     1Fam     1Story            5            5       1965
# ...         ...      ...        ...          ...          ...        ...
# 1449       Norm    Twnhs     SFoyer            5            7       1970
# 1450       Norm   Duplex     2Story            5            5       1974
# 1452       Norm   TwnhsE       SLvl            5            5       2005
# 1453       Norm     1Fam     1Story            5            5       2006
# 1459       Norm     1Fam     1Story            5            6       1965
#
#       YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 0             2003     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 1             1976     Gable  CompShg     MetalSd     MetalSd       None
# 4             2000     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 7             1973     Gable  CompShg     HdBoard     HdBoard      Stone
# 10            1965       Hip  CompShg     HdBoard     HdBoard       None
# ...            ...       ...      ...         ...         ...        ...
# 1449          1970     Gable  CompShg     CemntBd     CmentBd       None
# 1450          1974     Gable  CompShg     VinylSd     VinylSd       None
# 1452          2005     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 1453          2006     Gable  CompShg     VinylSd     VinylSd       None
# 1459          1965     Gable  CompShg     HdBoard     HdBoard       None
#
#       MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond  \
# 0          196.0        Gd        TA      PConc       Gd       TA
# 1            0.0        TA        TA     CBlock       Gd       TA
# 4          350.0        Gd        TA      PConc       Gd       TA
# 7          240.0        TA        TA     CBlock       Gd       TA
# 10           0.0        TA        TA     CBlock       TA       TA
# ...          ...       ...       ...        ...      ...      ...
# 1449         0.0        TA        TA     CBlock       Gd       TA
# 1450         0.0        TA        TA     CBlock       Gd       TA
# 1452        80.0        TA        TA      PConc       Gd       TA
# 1453         0.0        TA        TA      PConc       Gd       TA
# 1459         0.0        Gd        TA     CBlock       TA       TA
#
#      BsmtExposure BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  \
# 0              No          GLQ         706          Unf           0
# 1              Gd          ALQ         978          Unf           0
# 4              Av          GLQ         655          Unf           0
# 7              Mn          ALQ         859          BLQ          32
# 10             No          Rec         906          Unf           0
# ...           ...          ...         ...          ...         ...
# 1449           Av          GLQ         553          Unf           0
# 1450           No          Unf           0          Unf           0
# 1452           Gd          GLQ         547          Unf           0
# 1453           No          Unf           0          Unf           0
# 1459           No          BLQ         830          LwQ         290
#
#       BsmtUnfSF  TotalBsmtSF Heating HeatingQC CentralAir Electrical  \
# 0           150          856    GasA        Ex          Y      SBrkr
# 1           284         1262    GasA        Ex          Y      SBrkr
# 4           490         1145    GasA        Ex          Y      SBrkr
# 7           216         1107    GasA        Ex          Y      SBrkr
# 10          134         1040    GasA        Ex          Y      SBrkr
# ...         ...          ...     ...       ...        ...        ...
# 1449         77          630    GasA        Ex          Y      SBrkr
# 1450        896          896    GasA        TA          Y      SBrkr
# 1452          0          547    GasA        Gd          Y      SBrkr
# 1453       1140         1140    GasA        Ex          Y      SBrkr
# 1459        136         1256    GasA        Gd          Y      SBrkr
#
#       1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  BsmtFullBath  BsmtHalfBath  \
# 0          856       854             0       1710             1             0
# 1         1262         0             0       1262             0             1
# 4         1145      1053             0       2198             1             0
# 7         1107       983             0       2090             1             0
# 10        1040         0             0       1040             1             0
# ...        ...       ...           ...        ...           ...           ...
# 1449       630         0             0        630             1             0
# 1450       896       896             0       1792             0             0
# 1452      1072         0             0       1072             1             0
# 1453      1140         0             0       1140             0             0
# 1459      1256         0             0       1256             1             0
#
#       FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr KitchenQual  \
# 0            2         1             3             1          Gd
# 1            2         0             3             1          TA
# 4            2         1             4             1          Gd
# 7            2         1             3             1          TA
# 10           1         0             3             1          TA
# ...        ...       ...           ...           ...         ...
# 1449         1         0             1             1          Ex
# 1450         2         2             4             2          TA
# 1452         1         0             2             1          TA
# 1453         1         0             3             1          TA
# 1459         1         1             3             1          TA
#
#       TotRmsAbvGrd Functional  Fireplaces FireplaceQu GarageType  GarageYrBlt  \
# 0                8        Typ           0         DNE     Attchd       2003.0
# 1                6        Typ           1          TA     Attchd       1976.0
# 4                9        Typ           1          TA     Attchd       2000.0
# 7                7        Typ           2          TA     Attchd       1973.0
# 10               5        Typ           0         DNE     Detchd       1965.0
# ...            ...        ...         ...         ...        ...          ...
# 1449             3        Typ           0         DNE        DNE          0.0
# 1450             8        Typ           0         DNE        DNE          0.0
# 1452             5        Typ           0         DNE    Basment       2005.0
# 1453             6        Typ           0         DNE        DNE          0.0
# 1459             6        Typ           0         DNE     Attchd       1965.0
#
#      GarageFinish  GarageCars  GarageArea GarageQual GarageCond PavedDrive  \
# 0             RFn           2         548         TA         TA          Y
# 1             RFn           2         460         TA         TA          Y
# 4             RFn           3         836         TA         TA          Y
# 7             RFn           2         484         TA         TA          Y
# 10            Unf           1         384         TA         TA          Y
# ...           ...         ...         ...        ...        ...        ...
# 1449          DNE           0           0        DNE        DNE          Y
# 1450          DNE           0           0        DNE        DNE          Y
# 1452          Fin           2         525         TA         TA          Y
# 1453          DNE           0           0        DNE        DNE          Y
# 1459          Fin           1         276         TA         TA          Y
#
#       WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  \
# 0              0           61              0          0            0
# 1            298            0              0          0            0
# 4            192           84              0          0            0
# 7            235          204            228          0            0
# 10             0            0              0          0            0
# ...          ...          ...            ...        ...          ...
# 1449           0            0              0          0            0
# 1450          32           45              0          0            0
# 1452           0           28              0          0            0
# 1453          36           56              0          0            0
# 1459         736           68              0          0            0
#
#       PoolArea PoolQC Fence MiscFeature  MiscVal  MoSold  YrSold SaleType  \
# 0            0    DNE   DNE         DNE        0       2    2008       WD
# 1            0    DNE   DNE         DNE        0       5    2007       WD
# 4            0    DNE   DNE         DNE        0      12    2008       WD
# 7            0    DNE   DNE        Shed      350      11    2009       WD
# 10           0    DNE   DNE         DNE        0       2    2008       WD
# ...        ...    ...   ...         ...      ...     ...     ...      ...
# 1449         0    DNE   DNE         DNE        0       8    2006       WD
# 1450         0    DNE   DNE         DNE        0       9    2009       WD
# 1452         0    DNE   DNE         DNE        0       5    2006       WD
# 1453         0    DNE   DNE         DNE        0       7    2006       WD
# 1459         0    DNE   DNE         DNE        0       6    2008       WD
#
#      SaleCondition
# 0           Normal
# 1           Normal
# 4           Normal
# 7           Normal
# 10          Normal
# ...            ...
# 1449       Abnorml
# 1450        Normal
# 1452        Normal
# 1453       Abnorml
# 1459        Normal
#
# [764 rows x 80 columns]

# %%
hp[hp['GarageYrBlt']==0]
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 39      40          90       RL         65.0     6040   Pave   DNE      Reg
# 48      49         190       RM         33.0     4456   Pave   DNE      Reg
# 78      79          90       RL         72.0    10778   Pave   DNE      Reg
# 88      89          50  C (all)        105.0     8470   Pave   DNE      IR1
# 89      90          20       RL         60.0     8070   Pave   DNE      Reg
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1349  1350          70       RM         50.0     5250   Pave  Pave      Reg
# 1407  1408          20       RL          NaN     8780   Pave   DNE      IR1
# 1449  1450         180       RM         21.0     1533   Pave   DNE      Reg
# 1450  1451          90       RL         60.0     9000   Pave   DNE      Reg
# 1453  1454          20       RL         90.0    17217   Pave   DNE      Reg
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 39           Lvl    AllPub    Inside       Gtl      Edwards       Norm
# 48           Lvl    AllPub    Inside       Gtl      OldTown       Norm
# 78           Lvl    AllPub    Inside       Gtl       Sawyer       Norm
# 88           Lvl    AllPub    Corner       Gtl       IDOTRR      Feedr
# 89           Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# ...          ...       ...       ...       ...          ...        ...
# 1349         Lvl    AllPub    Inside       Gtl      OldTown       Norm
# 1407         Lvl    AllPub    Corner       Gtl      Mitchel       Norm
# 1449         Lvl    AllPub    Inside       Gtl      MeadowV       Norm
# 1450         Lvl    AllPub       FR2       Gtl        NAmes       Norm
# 1453         Lvl    AllPub    Inside       Gtl      Mitchel       Norm
#
#      Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 39         Norm   Duplex     1Story            4            5       1955
# 48         Norm   2fmCon     2Story            4            5       1920
# 78         Norm   Duplex     1Story            4            5       1968
# 88        Feedr     1Fam     1.5Fin            3            2       1915
# 89         Norm     1Fam     1Story            4            5       1994
# ...         ...      ...        ...          ...          ...        ...
# 1349       Norm     1Fam     2Story            8            5       1872
# 1407       Norm     1Fam     1Story            5            5       1985
# 1449       Norm    Twnhs     SFoyer            5            7       1970
# 1450       Norm   Duplex     2Story            5            5       1974
# 1453       Norm     1Fam     1Story            5            5       2006
#
#       YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 39            1955     Gable  CompShg     AsbShng     Plywood       None
# 48            2008     Gable  CompShg     MetalSd     MetalSd       None
# 78            1968       Hip  CompShg     HdBoard     HdBoard       None
# 88            1982       Hip  CompShg     Plywood     Plywood       None
# 89            1995     Gable  CompShg     VinylSd     VinylSd       None
# ...            ...       ...      ...         ...         ...        ...
# 1349          1987     Gable  CompShg     MetalSd     MetalSd       None
# 1407          1985     Gable  CompShg     HdBoard     Plywood       None
# 1449          1970     Gable  CompShg     CemntBd     CmentBd       None
# 1450          1974     Gable  CompShg     VinylSd     VinylSd       None
# 1453          2006     Gable  CompShg     VinylSd     VinylSd       None
#
#       MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond  \
# 39           0.0        TA        TA      PConc      DNE      DNE
# 48           0.0        TA        TA     BrkTil       TA       TA
# 78           0.0        TA        TA     CBlock       TA       TA
# 88           0.0        Fa        Fa     CBlock       TA       Fa
# 89           0.0        TA        TA      PConc       Gd       TA
# ...          ...       ...       ...        ...      ...      ...
# 1349         0.0        TA        Gd     BrkTil       TA       Fa
# 1407         0.0        TA        TA     CBlock       TA       TA
# 1449         0.0        TA        TA     CBlock       Gd       TA
# 1450         0.0        TA        TA     CBlock       Gd       TA
# 1453         0.0        TA        TA      PConc       Gd       TA
#
#      BsmtExposure BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  \
# 39            DNE          DNE           0          DNE           0
# 48             No          Unf           0          Unf           0
# 78             No          Unf           0          Unf           0
# 88             No          Unf           0          Unf           0
# 89             No          GLQ         588          Unf           0
# ...           ...          ...         ...          ...         ...
# 1349           No          LwQ         259          Unf           0
# 1407           No          ALQ         625          Unf           0
# 1449           Av          GLQ         553          Unf           0
# 1450           No          Unf           0          Unf           0
# 1453           No          Unf           0          Unf           0
#
#       BsmtUnfSF  TotalBsmtSF Heating HeatingQC CentralAir Electrical  \
# 39            0            0    GasA        TA          N      FuseP
# 48          736          736    GasA        Gd          Y      SBrkr
# 78         1768         1768    GasA        TA          N      SBrkr
# 88         1013         1013    GasA        TA          N      SBrkr
# 89          402          990    GasA        Ex          Y      SBrkr
# ...         ...          ...     ...       ...        ...        ...
# 1349        425          684    OthW        Fa          N      SBrkr
# 1407        208          833    GasA        Ex          Y      SBrkr
# 1449         77          630    GasA        Ex          Y      SBrkr
# 1450        896          896    GasA        TA          Y      SBrkr
# 1453       1140         1140    GasA        Ex          Y      SBrkr
#
#       1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  BsmtFullBath  BsmtHalfBath  \
# 39        1152         0             0       1152             0             0
# 48         736       716             0       1452             0             0
# 78        1768         0             0       1768             0             0
# 88        1013         0           513       1526             0             0
# 89         990         0             0        990             1             0
# ...        ...       ...           ...        ...           ...           ...
# 1349       938      1215           205       2358             0             0
# 1407       833         0             0        833             1             0
# 1449       630         0             0        630             1             0
# 1450       896       896             0       1792             0             0
# 1453      1140         0             0       1140             0             0
#
#       FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr KitchenQual  \
# 39           2         0             2             2          Fa
# 48           2         0             2             3          TA
# 78           2         0             4             2          TA
# 88           1         0             2             1          Fa
# 89           1         0             3             1          TA
# ...        ...       ...           ...           ...         ...
# 1349         2         0             4             1          TA
# 1407         1         0             3             1          TA
# 1449         1         0             1             1          Ex
# 1450         2         2             4             2          TA
# 1453         1         0             3             1          TA
#
#       TotRmsAbvGrd Functional  Fireplaces FireplaceQu GarageType  GarageYrBlt  \
# 39               6        Typ           0         DNE        DNE          0.0
# 48               8        Typ           0         DNE        DNE          0.0
# 78               8        Typ           0         DNE        DNE          0.0
# 88               6        Typ           0         DNE        DNE          0.0
# 89               5        Typ           0         DNE        DNE          0.0
# ...            ...        ...         ...         ...        ...          ...
# 1349             8        Typ           0         DNE        DNE          0.0
# 1407             5        Typ           0         DNE        DNE          0.0
# 1449             3        Typ           0         DNE        DNE          0.0
# 1450             8        Typ           0         DNE        DNE          0.0
# 1453             6        Typ           0         DNE        DNE          0.0
#
#      GarageFinish  GarageCars  GarageArea GarageQual GarageCond PavedDrive  \
# 39            DNE           0           0        DNE        DNE          N
# 48            DNE           0           0        DNE        DNE          N
# 78            DNE           0           0        DNE        DNE          Y
# 88            DNE           0           0        DNE        DNE          N
# 89            DNE           0           0        DNE        DNE          Y
# ...           ...         ...         ...        ...        ...        ...
# 1349          DNE           0           0        DNE        DNE          Y
# 1407          DNE           0           0        DNE        DNE          Y
# 1449          DNE           0           0        DNE        DNE          Y
# 1450          DNE           0           0        DNE        DNE          Y
# 1453          DNE           0           0        DNE        DNE          Y
#
#       WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  \
# 39             0            0              0          0            0
# 48             0            0            102          0            0
# 78             0            0              0          0            0
# 88             0            0            156          0            0
# 89             0            0              0          0            0
# ...          ...          ...            ...        ...          ...
# 1349           0           54             20          0            0
# 1407           0            0              0          0            0
# 1449           0            0              0          0            0
# 1450          32           45              0          0            0
# 1453          36           56              0          0            0
#
#       PoolArea PoolQC  Fence MiscFeature  MiscVal  MoSold  YrSold SaleType  \
# 39           0    DNE    DNE         DNE        0       6    2008       WD
# 48           0    DNE    DNE         DNE        0       6    2009      New
# 78           0    DNE    DNE         DNE        0       4    2010       WD
# 88           0    DNE  MnPrv         DNE        0      10    2009    ConLD
# 89           0    DNE    DNE         DNE        0       8    2007       WD
# ...        ...    ...    ...         ...      ...     ...     ...      ...
# 1349         0    DNE    DNE         DNE        0      12    2008       WD
# 1407         0    DNE  MnPrv         DNE        0       3    2009       WD
# 1449         0    DNE    DNE         DNE        0       8    2006       WD
# 1450         0    DNE    DNE         DNE        0       9    2009       WD
# 1453         0    DNE    DNE         DNE        0       7    2006       WD
#
#      SaleCondition
# 39         AdjLand
# 48         Partial
# 78          Normal
# 88         Abnorml
# 89          Normal
# ...            ...
# 1349        Normal
# 1407        Normal
# 1449       Abnorml
# 1450        Normal
# 1453       Abnorml
#
# [81 rows x 80 columns]

# %%
hp.loc[hp.GarageYrBlt==0]
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 39      40          90       RL         65.0     6040   Pave   DNE      Reg
# 48      49         190       RM         33.0     4456   Pave   DNE      Reg
# 78      79          90       RL         72.0    10778   Pave   DNE      Reg
# 88      89          50  C (all)        105.0     8470   Pave   DNE      IR1
# 89      90          20       RL         60.0     8070   Pave   DNE      Reg
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1349  1350          70       RM         50.0     5250   Pave  Pave      Reg
# 1407  1408          20       RL          NaN     8780   Pave   DNE      IR1
# 1449  1450         180       RM         21.0     1533   Pave   DNE      Reg
# 1450  1451          90       RL         60.0     9000   Pave   DNE      Reg
# 1453  1454          20       RL         90.0    17217   Pave   DNE      Reg
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 39           Lvl    AllPub    Inside       Gtl      Edwards       Norm
# 48           Lvl    AllPub    Inside       Gtl      OldTown       Norm
# 78           Lvl    AllPub    Inside       Gtl       Sawyer       Norm
# 88           Lvl    AllPub    Corner       Gtl       IDOTRR      Feedr
# 89           Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# ...          ...       ...       ...       ...          ...        ...
# 1349         Lvl    AllPub    Inside       Gtl      OldTown       Norm
# 1407         Lvl    AllPub    Corner       Gtl      Mitchel       Norm
# 1449         Lvl    AllPub    Inside       Gtl      MeadowV       Norm
# 1450         Lvl    AllPub       FR2       Gtl        NAmes       Norm
# 1453         Lvl    AllPub    Inside       Gtl      Mitchel       Norm
#
#      Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 39         Norm   Duplex     1Story            4            5       1955
# 48         Norm   2fmCon     2Story            4            5       1920
# 78         Norm   Duplex     1Story            4            5       1968
# 88        Feedr     1Fam     1.5Fin            3            2       1915
# 89         Norm     1Fam     1Story            4            5       1994
# ...         ...      ...        ...          ...          ...        ...
# 1349       Norm     1Fam     2Story            8            5       1872
# 1407       Norm     1Fam     1Story            5            5       1985
# 1449       Norm    Twnhs     SFoyer            5            7       1970
# 1450       Norm   Duplex     2Story            5            5       1974
# 1453       Norm     1Fam     1Story            5            5       2006
#
#       YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 39            1955     Gable  CompShg     AsbShng     Plywood       None
# 48            2008     Gable  CompShg     MetalSd     MetalSd       None
# 78            1968       Hip  CompShg     HdBoard     HdBoard       None
# 88            1982       Hip  CompShg     Plywood     Plywood       None
# 89            1995     Gable  CompShg     VinylSd     VinylSd       None
# ...            ...       ...      ...         ...         ...        ...
# 1349          1987     Gable  CompShg     MetalSd     MetalSd       None
# 1407          1985     Gable  CompShg     HdBoard     Plywood       None
# 1449          1970     Gable  CompShg     CemntBd     CmentBd       None
# 1450          1974     Gable  CompShg     VinylSd     VinylSd       None
# 1453          2006     Gable  CompShg     VinylSd     VinylSd       None
#
#       MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond  \
# 39           0.0        TA        TA      PConc      DNE      DNE
# 48           0.0        TA        TA     BrkTil       TA       TA
# 78           0.0        TA        TA     CBlock       TA       TA
# 88           0.0        Fa        Fa     CBlock       TA       Fa
# 89           0.0        TA        TA      PConc       Gd       TA
# ...          ...       ...       ...        ...      ...      ...
# 1349         0.0        TA        Gd     BrkTil       TA       Fa
# 1407         0.0        TA        TA     CBlock       TA       TA
# 1449         0.0        TA        TA     CBlock       Gd       TA
# 1450         0.0        TA        TA     CBlock       Gd       TA
# 1453         0.0        TA        TA      PConc       Gd       TA
#
#      BsmtExposure BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  \
# 39            DNE          DNE           0          DNE           0
# 48             No          Unf           0          Unf           0
# 78             No          Unf           0          Unf           0
# 88             No          Unf           0          Unf           0
# 89             No          GLQ         588          Unf           0
# ...           ...          ...         ...          ...         ...
# 1349           No          LwQ         259          Unf           0
# 1407           No          ALQ         625          Unf           0
# 1449           Av          GLQ         553          Unf           0
# 1450           No          Unf           0          Unf           0
# 1453           No          Unf           0          Unf           0
#
#       BsmtUnfSF  TotalBsmtSF Heating HeatingQC CentralAir Electrical  \
# 39            0            0    GasA        TA          N      FuseP
# 48          736          736    GasA        Gd          Y      SBrkr
# 78         1768         1768    GasA        TA          N      SBrkr
# 88         1013         1013    GasA        TA          N      SBrkr
# 89          402          990    GasA        Ex          Y      SBrkr
# ...         ...          ...     ...       ...        ...        ...
# 1349        425          684    OthW        Fa          N      SBrkr
# 1407        208          833    GasA        Ex          Y      SBrkr
# 1449         77          630    GasA        Ex          Y      SBrkr
# 1450        896          896    GasA        TA          Y      SBrkr
# 1453       1140         1140    GasA        Ex          Y      SBrkr
#
#       1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  BsmtFullBath  BsmtHalfBath  \
# 39        1152         0             0       1152             0             0
# 48         736       716             0       1452             0             0
# 78        1768         0             0       1768             0             0
# 88        1013         0           513       1526             0             0
# 89         990         0             0        990             1             0
# ...        ...       ...           ...        ...           ...           ...
# 1349       938      1215           205       2358             0             0
# 1407       833         0             0        833             1             0
# 1449       630         0             0        630             1             0
# 1450       896       896             0       1792             0             0
# 1453      1140         0             0       1140             0             0
#
#       FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr KitchenQual  \
# 39           2         0             2             2          Fa
# 48           2         0             2             3          TA
# 78           2         0             4             2          TA
# 88           1         0             2             1          Fa
# 89           1         0             3             1          TA
# ...        ...       ...           ...           ...         ...
# 1349         2         0             4             1          TA
# 1407         1         0             3             1          TA
# 1449         1         0             1             1          Ex
# 1450         2         2             4             2          TA
# 1453         1         0             3             1          TA
#
#       TotRmsAbvGrd Functional  Fireplaces FireplaceQu GarageType  GarageYrBlt  \
# 39               6        Typ           0         DNE        DNE          0.0
# 48               8        Typ           0         DNE        DNE          0.0
# 78               8        Typ           0         DNE        DNE          0.0
# 88               6        Typ           0         DNE        DNE          0.0
# 89               5        Typ           0         DNE        DNE          0.0
# ...            ...        ...         ...         ...        ...          ...
# 1349             8        Typ           0         DNE        DNE          0.0
# 1407             5        Typ           0         DNE        DNE          0.0
# 1449             3        Typ           0         DNE        DNE          0.0
# 1450             8        Typ           0         DNE        DNE          0.0
# 1453             6        Typ           0         DNE        DNE          0.0
#
#      GarageFinish  GarageCars  GarageArea GarageQual GarageCond PavedDrive  \
# 39            DNE           0           0        DNE        DNE          N
# 48            DNE           0           0        DNE        DNE          N
# 78            DNE           0           0        DNE        DNE          Y
# 88            DNE           0           0        DNE        DNE          N
# 89            DNE           0           0        DNE        DNE          Y
# ...           ...         ...         ...        ...        ...        ...
# 1349          DNE           0           0        DNE        DNE          Y
# 1407          DNE           0           0        DNE        DNE          Y
# 1449          DNE           0           0        DNE        DNE          Y
# 1450          DNE           0           0        DNE        DNE          Y
# 1453          DNE           0           0        DNE        DNE          Y
#
#       WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  \
# 39             0            0              0          0            0
# 48             0            0            102          0            0
# 78             0            0              0          0            0
# 88             0            0            156          0            0
# 89             0            0              0          0            0
# ...          ...          ...            ...        ...          ...
# 1349           0           54             20          0            0
# 1407           0            0              0          0            0
# 1449           0            0              0          0            0
# 1450          32           45              0          0            0
# 1453          36           56              0          0            0
#
#       PoolArea PoolQC  Fence MiscFeature  MiscVal  MoSold  YrSold SaleType  \
# 39           0    DNE    DNE         DNE        0       6    2008       WD
# 48           0    DNE    DNE         DNE        0       6    2009      New
# 78           0    DNE    DNE         DNE        0       4    2010       WD
# 88           0    DNE  MnPrv         DNE        0      10    2009    ConLD
# 89           0    DNE    DNE         DNE        0       8    2007       WD
# ...        ...    ...    ...         ...      ...     ...     ...      ...
# 1349         0    DNE    DNE         DNE        0      12    2008       WD
# 1407         0    DNE  MnPrv         DNE        0       3    2009       WD
# 1449         0    DNE    DNE         DNE        0       8    2006       WD
# 1450         0    DNE    DNE         DNE        0       9    2009       WD
# 1453         0    DNE    DNE         DNE        0       7    2006       WD
#
#      SaleCondition
# 39         AdjLand
# 48         Partial
# 78          Normal
# 88         Abnorml
# 89          Normal
# ...            ...
# 1349        Normal
# 1407        Normal
# 1449       Abnorml
# 1450        Normal
# 1453       Abnorml
#
# [81 rows x 80 columns]

# %%
# adds the column 'GarageYrModified' and sets it == to 'YearRemodAdd' or 'GarageYrBlt'

# https://www.redfin.com/news/does-a-garage-add-value-to-a-home/

# according to the above, having a garage does not seem to impact houses in the midwest (besides Chicago)

hp['GarageYrModified'] = np.where(hp['YearRemodAdd']>hp['YearBuilt'], hp['YearRemodAdd'], hp['GarageYrBlt'])

hp['GarageYrModified'] = np.where(hp['GarageYrModified']==0, hp['YearRemodAdd'], hp['YearBuilt'])
hp['GarageYrModified'] = pd.to_numeric(hp['GarageYrModified'])

# %%
hp[hp['GarageYrModified']==0]
# Out:
# Empty DataFrame
# Columns: [Id, MSSubClass, MSZoning, LotFrontage, LotArea, Street, Alley, LotShape, LandContour, Utilities, LotConfig, LandSlope, Neighborhood, Condition1, Condition2, BldgType, HouseStyle, OverallQual, OverallCond, YearBuilt, YearRemodAdd, RoofStyle, RoofMatl, Exterior1st, Exterior2nd, MasVnrType, MasVnrArea, ExterQual, ExterCond, Foundation, BsmtQual, BsmtCond, BsmtExposure, BsmtFinType1, BsmtFinSF1, BsmtFinType2, BsmtFinSF2, BsmtUnfSF, TotalBsmtSF, Heating, HeatingQC, CentralAir, Electrical, 1stFlrSF, 2ndFlrSF, LowQualFinSF, GrLivArea, BsmtFullBath, BsmtHalfBath, FullBath, HalfBath, BedroomAbvGr, KitchenAbvGr, KitchenQual, TotRmsAbvGrd, Functional, Fireplaces, FireplaceQu, GarageType, GarageYrBlt, GarageFinish, GarageCars, GarageArea, GarageQual, GarageCond, PavedDrive, WoodDeckSF, OpenPorchSF, EnclosedPorch, 3SsnPorch, ScreenPorch, PoolArea, PoolQC, Fence, MiscFeature, MiscVal, MoSold, YrSold, SaleType, SaleCondition, GarageYrModified]
# Index: []

# %%
hp[hp['GarageYrModified'].isna()]
# Out:
# Empty DataFrame
# Columns: [Id, MSSubClass, MSZoning, LotFrontage, LotArea, Street, Alley, LotShape, LandContour, Utilities, LotConfig, LandSlope, Neighborhood, Condition1, Condition2, BldgType, HouseStyle, OverallQual, OverallCond, YearBuilt, YearRemodAdd, RoofStyle, RoofMatl, Exterior1st, Exterior2nd, MasVnrType, MasVnrArea, ExterQual, ExterCond, Foundation, BsmtQual, BsmtCond, BsmtExposure, BsmtFinType1, BsmtFinSF1, BsmtFinType2, BsmtFinSF2, BsmtUnfSF, TotalBsmtSF, Heating, HeatingQC, CentralAir, Electrical, 1stFlrSF, 2ndFlrSF, LowQualFinSF, GrLivArea, BsmtFullBath, BsmtHalfBath, FullBath, HalfBath, BedroomAbvGr, KitchenAbvGr, KitchenQual, TotRmsAbvGrd, Functional, Fireplaces, FireplaceQu, GarageType, GarageYrBlt, GarageFinish, GarageCars, GarageArea, GarageQual, GarageCond, PavedDrive, WoodDeckSF, OpenPorchSF, EnclosedPorch, 3SsnPorch, ScreenPorch, PoolArea, PoolQC, Fence, MiscFeature, MiscVal, MoSold, YrSold, SaleType, SaleCondition, GarageYrModified]
# Index: []

# %% [markdown]
# ## Replace Appropriate Columns' NaNs with 'DNE'

# %%
obj_DNE_list = [i for i in cols_w_nan_obj if i not in should_not_have_nan_obj]

# %%
num_DNE_list = [i for i in cols_w_nan_num if i not in should_not_have_nan_num]

# %%
nan_col_obj_list_fillna(hp, obj_DNE_list)

# %%
nan_col_obj_list_fillna(hp, num_DNE_list)

# %% [markdown]
# ### Check if There Are Any NaNs Remaining

# %%
cols_w_nan_obj2 = []

nan_col_list(hp, cols_w_nan_obj, cols_w_nan_obj2)
# Out:
# []

# %%
cols_w_nan_num2 = []

nan_col_list(hp, cols_w_nan_num, cols_w_nan_num2)
# Out:
# ['LotFrontage']

# %%
hp.to_csv('../hp_for_dummies.csv', index=False)

# %% [markdown]
# # Resume Here

# %% [markdown]
# ### Ridge

# %%
ridge = Ridge(random_state=0, max_iter=100000)

alphas = np.logspace(-2, 3, 100)

gparam_ridge = [{'alpha': alphas}]
n_folds=ms.StratifiedKFold(n_splits=5, random_state=0, shuffle=True)

gs_ridge = GridSearchCV(ridge, gparam_ridge, cv=n_folds)
# %time gs_ridge.fit(xtrain, ytrain)
# Out:
# C:\Users\tdcho\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:672: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   % (min_groups, self.n_splits)), UserWarning)
# Wall time: 18.8 s
# GridSearchCV(cv=StratifiedKFold(n_splits=5, random_state=0, shuffle=True),
#              error_score=nan,
#              estimator=Ridge(alpha=1.0, copy_X=True, fit_intercept=True,
#                              max_iter=100000, normalize=False, random_state=0,
#                              solver='auto', tol=0.001),
#              iid='deprecated', n_jobs=None,
#              param_grid=[{'alpha': array([1.00000000e-02, 1.12332403e-02, 1.26185688e-02, 1.41747416e-02,
#        1.59228279e-02, 1...
#        1.09749877e+02, 1.23284674e+02, 1.38488637e+02, 1.55567614e+02,
#        1.74752840e+02, 1.96304065e+02, 2.20513074e+02, 2.47707636e+02,
#        2.78255940e+02, 3.12571585e+02, 3.51119173e+02, 3.94420606e+02,
#        4.43062146e+02, 4.97702356e+02, 5.59081018e+02, 6.28029144e+02,
#        7.05480231e+02, 7.92482898e+02, 8.90215085e+02, 1.00000000e+03])}],
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=0)

# %%
print(gs_ridge.best_params_)
print(gs_ridge.best_score_)
# Out:
# {'alpha': 155.56761439304722}
# 0.4788736216115265

# %%
gs_ridge.cv_results_['mean_test_score']
# Out:
# array([0.26810444, 0.26929041, 0.27042562, 0.27152406, 0.27259862,
#        0.2736609 , 0.27472109, 0.27578791, 0.27686863, 0.27796905,
#        0.27909369, 0.28024586, 0.28142789, 0.28264133, 0.28388723,
#        0.28516643, 0.28647985, 0.28782886, 0.28921551, 0.29064286,
#        0.29211516, 0.29363799, 0.2952183 , 0.29686436, 0.29858558,
#        0.30039223, 0.30229511, 0.30430513, 0.30643287, 0.30868819,
#        0.31107982, 0.3136151 , 0.31629978, 0.3191379 , 0.32213179,
#        0.32528218, 0.32858828, 0.33204797, 0.33565786, 0.33941348,
#        0.34330925, 0.34733854, 0.35149358, 0.35576538, 0.36014366,
#        0.36461676, 0.36917161, 0.3737937 , 0.37846724, 0.38317524,
#        0.38789977, 0.39262222, 0.39732367, 0.40198518, 0.40658822,
#        0.41111497, 0.41554868, 0.41987393, 0.42407692, 0.42814559,
#        0.43206979, 0.43584135, 0.43945404, 0.44290362, 0.44618764,
#        0.44930541, 0.45225776, 0.45504684, 0.45767589, 0.46014891,
#        0.46247036, 0.46464476, 0.46667624, 0.46856807, 0.47032213,
#        0.47193834, 0.47341415, 0.47474399, 0.47591879, 0.47692565,
#        0.47774763, 0.47836362, 0.47874855, 0.47887362, 0.47870686,
#        0.47821374, 0.47735798, 0.47610241, 0.4744099 , 0.47224429,
#        0.46957129, 0.4663593 , 0.46258015, 0.45820972, 0.45322848,
#        0.4476219 , 0.44138072, 0.43450122, 0.42698529, 0.41884051])

# %%
plt.scatter(gs_ridge.cv_results_['param_alpha'], gs_ridge.cv_results_['mean_test_score'])

# %%
alphas = np.linspace(1e-2, 600, 100)

gparam_ridge = [{'alpha': alphas}]
n_folds=ms.StratifiedKFold(n_splits=5, random_state=0, shuffle=True)

gs_ridge = GridSearchCV(ridge, gparam_ridge, cv=n_folds)
# %time gs_ridge.fit(xtrain, ytrain)

print(gs_ridge.best_params_)
print(gs_ridge.best_score_)
plt.scatter(gs_ridge.cv_results_['param_alpha'], gs_ridge.cv_results_['mean_test_score'])
# Out:
# C:\Users\tdcho\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:672: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   % (min_groups, self.n_splits)), UserWarning)
# Wall time: 19 s
# {'alpha': 157.5831313131313}
# 0.4788701364796492

# %%
alphas = np.linspace(50, 200, 50)

gparam_ridge = [{'alpha': alphas}]
n_folds=ms.StratifiedKFold(n_splits=5, random_state=0, shuffle=True)

gs_ridge = GridSearchCV(ridge, gparam_ridge, cv=n_folds)
# %time gs_ridge.fit(xtrain, ytrain)

print(gs_ridge.best_params_)
print(gs_ridge.best_score_)
plt.scatter(gs_ridge.cv_results_['param_alpha'], gs_ridge.cv_results_['mean_test_score'])
# Out:
# C:\Users\tdcho\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:672: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   % (min_groups, self.n_splits)), UserWarning)
# Wall time: 4.17 s
# {'alpha': 154.0816326530612}
# 0.478873892329539

# %%
alphas = np.linspace(120, 180, 50)

gparam_ridge = [{'alpha': alphas}]
n_folds=ms.StratifiedKFold(n_splits=5, random_state=0, shuffle=True)

gs_ridge = GridSearchCV(ridge, gparam_ridge, cv=n_folds)
# %time gs_ridge.fit(xtrain, ytrain)

print(gs_ridge.best_params_)
print(gs_ridge.best_score_)
plt.scatter(gs_ridge.cv_results_['param_alpha'], gs_ridge.cv_results_['mean_test_score'])
# Out:
# C:\Users\tdcho\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:672: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   % (min_groups, self.n_splits)), UserWarning)
# Wall time: 4.27 s
# {'alpha': 154.28571428571428}
# 0.4788739723848237

# %% [markdown]
# ### Lasso

# %%
lasso = Lasso(random_state=0, max_iter=100000)

alphas = np.logspace(-2, 3, 100)

gparam_lasso = [{'alpha': alphas}]
n_folds=ms.StratifiedKFold(n_splits=5, random_state=0, shuffle=True)

gs_lasso = GridSearchCV(lasso, gparam_lasso, cv=n_folds, refit=True)
# %time gs_lasso.fit(xtrain, ytrain)
# Out:
# C:\Users\tdcho\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:672: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   % (min_groups, self.n_splits)), UserWarning)
# Wall time: 17.3 s
# GridSearchCV(cv=StratifiedKFold(n_splits=5, random_state=0, shuffle=True),
#              error_score=nan,
#              estimator=Lasso(alpha=1.0, copy_X=True, fit_intercept=True,
#                              max_iter=100000, normalize=False, positive=False,
#                              precompute=False, random_state=0,
#                              selection='cyclic', tol=0.0001, warm_start=False),
#              iid='deprecated', n_jobs=None,
#              param_grid=[{'alpha': array([1.00000000e-02, 1.1233...
#        1.09749877e+02, 1.23284674e+02, 1.38488637e+02, 1.55567614e+02,
#        1.74752840e+02, 1.96304065e+02, 2.20513074e+02, 2.47707636e+02,
#        2.78255940e+02, 3.12571585e+02, 3.51119173e+02, 3.94420606e+02,
#        4.43062146e+02, 4.97702356e+02, 5.59081018e+02, 6.28029144e+02,
#        7.05480231e+02, 7.92482898e+02, 8.90215085e+02, 1.00000000e+03])}],
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=0)

# %%
print(gs_lasso.best_params_)
print(gs_lasso.best_score_)
# Out:
# {'alpha': 0.23101297000831592}
# 0.4716591897533867

# %%
plt.scatter(gs_lasso.cv_results_['param_alpha'], gs_lasso.cv_results_['mean_test_score'])

# %%
alphas = np.linspace(1e-2, 5, 50)

gparam_lasso = [{'alpha': alphas}]
n_folds=ms.StratifiedKFold(n_splits=5, random_state=0, shuffle=True)

gs_lasso = GridSearchCV(lasso, gparam_lasso, cv=n_folds, refit=True)
# %time gs_lasso.fit(xtrain, ytrain)

print(gs_lasso.best_params_)
print(gs_lasso.best_score_)
plt.scatter(gs_lasso.cv_results_['param_alpha'], gs_lasso.cv_results_['mean_test_score'])
# Out:
# C:\Users\tdcho\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:672: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   % (min_groups, self.n_splits)), UserWarning)
# Wall time: 7.22 s
# {'alpha': 0.2136734693877551}
# 0.47114383702561735

# %%
alphas = np.linspace(1e-2, 0.5, 50)

gparam_lasso = [{'alpha': alphas}]
n_folds=ms.StratifiedKFold(n_splits=5, random_state=0, shuffle=True)

gs_lasso = GridSearchCV(lasso, gparam_lasso, cv=n_folds, refit=True)
# %time gs_lasso.fit(xtrain, ytrain)

print(gs_lasso.best_params_)
print(gs_lasso.best_score_)
plt.scatter(gs_lasso.cv_results_['param_alpha'], gs_lasso.cv_results_['mean_test_score'])
# Out:
# C:\Users\tdcho\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:672: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   % (min_groups, self.n_splits)), UserWarning)
# Wall time: 8.6 s
# {'alpha': 0.23}
# 0.47165336950602954

# %% [markdown]
# ### Gradient Boosting

# %%
from sklearn.ensemble import GradientBoostingRegressor
gbm = GradientBoostingRegressor(random_state=0, loss='ls',
                                min_impurity_decrease=0.1, 
                                warm_start=False)

learningrate = [0.0001, 0.001, 0.01, 0.1, 1] # subsequently, fine tune
nestimators = [5, 10, 50, 100, 200, 500, 1000,
               1500, 2000, 5000]
# subsamples = np.linspace(0, 1, 100)
maxfeatures = [9, 40, len(xtrain.columns)]
maxdepth = range(1, 5)

ytrain_array = ytrain.values.flatten()

gparam_gbm = [{'learning_rate': learningrate},
              {'n_estimators': nestimators},
#               {'subsample': subsamples}, 
              {'max_features': maxfeatures},
              {'max_depth': maxdepth}]

n_folds=ms.StratifiedKFold(n_splits=5, random_state=0, shuffle=True)

gs_gbm = GridSearchCV(gbm, gparam_gbm, cv=n_folds, refit=True, n_jobs=-1)
# %time gs_gbm.fit(xtrain, ytrain_array)
# Out:
# C:\Users\tdcho\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:672: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   % (min_groups, self.n_splits)), UserWarning)
# Wall time: 42.2 s
# GridSearchCV(cv=StratifiedKFold(n_splits=5, random_state=0, shuffle=True),
#              error_score=nan,
#              estimator=GradientBoostingRegressor(alpha=0.9, ccp_alpha=0.0,
#                                                  criterion='friedman_mse',
#                                                  init=None, learning_rate=0.1,
#                                                  loss='ls', max_depth=3,
#                                                  max_features=None,
#                                                  max_leaf_nodes=None,
#                                                  min_impurity_decrease=0.1,
#                                                  min_impurity_split=None,
#                                                  min_samples_leaf=1,
#                                                  min_samples_split=2,...
#                                                  random_state=0, subsample=1.0,
#                                                  tol=0.0001,
#                                                  validation_fraction=0.1,
#                                                  verbose=0, warm_start=False),
#              iid='deprecated', n_jobs=-1,
#              param_grid=[{'learning_rate': [0.0001, 0.001, 0.01, 0.1, 1]},
#                          {'n_estimators': [5, 10, 50, 100, 200, 500, 1000, 1500,
#                                            2000, 5000]},
#                          {'max_features': [9, 40, 302]},
#                          {'max_depth': range(1, 5)}],
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=0)

# %%
print(gs_gbm.best_params_)
print(gs_gbm.best_score_)
# Out:
# {'max_features': 40}
# 0.5705116010999469

# %%
gbm_imp_feat = sorted(zip(xtrain.columns, gs_gbm.best_estimator_.feature_importances_), key=lambda t:t[1], reverse=True)
gbm_imp_feat
# Out:
# [('LotArea', 0.17293200780701654),
#  ('MSSubClass', 0.11158853739363708),
#  ('1stFlrSF', 0.063897704818399),
#  ('LotConfig_Corner', 0.06238008832696404),
#  ('GrLivArea', 0.050553741838930744),
#  ('GarageArea', 0.05027369056147082),
#  ('BldgType_1Fam', 0.039309892308460784),
#  ('BldgType_Twnhs', 0.03726798479943025),
#  ('LotShape_IR3', 0.022313622404028677),
#  ('TotalBsmtSF', 0.021980880309380918),
#  ('GarageYrModified', 0.01948051844527163),
#  ('YearBuilt', 0.01864397527205338),
#  ('OverallQual', 0.017006001125874557),
#  ('LotConfig_CulDSac', 0.01677891393452744),
#  ('GarageType_Detchd', 0.015886899355166118),
#  ('PoolQC_Gd', 0.015533798375298072),
#  ('PoolQC_DNE', 0.013594387640437309),
#  ('MSZoning_RL', 0.013534886582522384),
#  ('YearRemodAdd', 0.012503317536323366),
#  ('OpenPorchSF', 0.012092222918066425),
#  ('LotShape_IR2', 0.00938789117519495),
#  ('PoolArea', 0.00894984443214236),
#  ('Foundation_Wood', 0.008061680870290735),
#  ('MSZoning_RM', 0.008037584150513146),
#  ('TotRmsAbvGrd', 0.007246533023948179),
#  ('LandSlope_Mod', 0.007036189557096374),
#  ('EnclosedPorch', 0.006862919310336985),
#  ('BldgType_2fmCon', 0.006617560446821523),
#  ('MasVnrArea', 0.0065798951390951795),
#  ('Neighborhood_Gilbert', 0.0065593607161203125),
#  ('GarageCars', 0.005854688079111411),
#  ('BldgType_TwnhsE', 0.005471361604267387),
#  ('BedroomAbvGr', 0.005148193097244715),
#  ('BsmtFinSF1', 0.004639927103615089),
#  ('WoodDeckSF', 0.004137320466372581),
#  ('HouseStyle_1Story', 0.003876080040029),
#  ('BsmtFullBath', 0.0038229834486862443),
#  ('GarageYrBlt', 0.00352998784967265),
#  ('LandSlope_Gtl', 0.0032698776633715678),
#  ('PoolQC_Ex', 0.0032576643397198473),
#  ('GarageFinish_Unf', 0.003096716916185532),
#  ('BsmtUnfSF', 0.0029825141756284843),
#  ('BsmtQual_Gd', 0.002875816788520199),
#  ('GarageType_Basment', 0.0026490537619394223),
#  ('Exterior2nd_Stucco', 0.0026409773720574713),
#  ('RoofMatl_ClyTile', 0.002373788048923139),
#  ('2ndFlrSF', 0.002371638230054048),
#  ('LotConfig_Inside', 0.0023357079708156),
#  ('Fence_DNE', 0.002292850004141373),
#  ('LandContour_HLS', 0.0021579544715584547),
#  ('KitchenQual_Fa', 0.00204284600416255),
#  ('FireplaceQu_Gd', 0.0020320100538812258),
#  ('Alley_Grvl', 0.0019692454881297893),
#  ('Alley_DNE', 0.001878902605499371),
#  ('Condition1_RRAn', 0.0018721894632217255),
#  ('LotShape_Reg', 0.0018678041491691298),
#  ('Neighborhood_NoRidge', 0.001842228713256754),
#  ('3SsnPorch', 0.0017704752620097488),
#  ('GarageType_Attchd', 0.001712114354357842),
#  ('Heating_GasA', 0.00170346237467744),
#  ('LotShape_IR1', 0.0017029581573649766),
#  ('Foundation_CBlock', 0.0016997484976307082),
#  ('BsmtFinSF2', 0.0016298718490433614),
#  ('ExterQual_Fa', 0.0015591240222427455),
#  ('Exterior1st_Stucco', 0.00142182257292433),
#  ('YrSold', 0.0014007339741797416),
#  ('BsmtExposure_Av', 0.0013145436792099056),
#  ('MoSold', 0.0013008545030458488),
#  ('LotConfig_FR3', 0.0012883788733312293),
#  ('HouseStyle_1.5Fin', 0.0011842490941849516),
#  ('OverallCond', 0.0011741659643257243),
#  ('Neighborhood_CollgCr', 0.0011022924660760366),
#  ('Condition1_Feedr', 0.0010963080214187132),
#  ('Exterior2nd_Plywood', 0.0010785719844078774),
#  ('RoofMatl_WdShngl', 0.0010757068142365643),
#  ('Street_Pave', 0.001046859524055138),
#  ('Electrical_FuseA', 0.0010337257768408565),
#  ('MasVnrType_Stone', 0.0010273034185415148),
#  ('Neighborhood_NridgHt', 0.0009962289950922294),
#  ('HouseStyle_2Story', 0.0009900423195198316),
#  ('Heating_Grav', 0.000982497569855143),
#  ('BldgType_Duplex', 0.0009291319759472123),
#  ('PavedDrive_P', 0.0009256495556152434),
#  ('Condition1_PosA', 0.0008847911242907659),
#  ('Neighborhood_IDOTRR', 0.0008740032724556543),
#  ('BsmtFinType2_Rec', 0.0007735065039805195),
#  ('BsmtFinType1_GLQ', 0.0007247517923083379),
#  ('GarageType_CarPort', 0.0006681691384742279),
#  ('ExterCond_Fa', 0.0006651701328344626),
#  ('BsmtExposure_No', 0.0006637166091485757),
#  ('Foundation_BrkTil', 0.0006247809668711305),
#  ('Exterior2nd_Brk Cmn', 0.0005977163552874314),
#  ('Exterior1st_CBlock', 0.0005796371531983079),
#  ('HouseStyle_SLvl', 0.000569211886080278),
#  ('BsmtExposure_Gd', 0.0005514015627411468),
#  ('GarageQual_DNE', 0.0005485819959072734),
#  ('Exterior1st_HdBoard', 0.0005411680058453805),
#  ('HalfBath', 0.0005127533773279165),
#  ('FireplaceQu_Fa', 0.0005076477064300742),
#  ('BsmtFinType1_BLQ', 0.0005038870374404446),
#  ('Fireplaces', 0.00047559098938525945),
#  ('GarageCond_Fa', 0.00047365685244255955),
#  ('Condition1_Norm', 0.0004676459548687607),
#  ('CentralAir_N', 0.000413937506488709),
#  ('Exterior1st_MetalSd', 0.0004008319236447855),
#  ('KitchenAbvGr', 0.00038930467908503943),
#  ('BsmtQual_Ex', 0.000366304655891751),
#  ('Exterior1st_Plywood', 0.0003472803206374096),
#  ('SaleCondition_Abnorml', 0.00031966113693598236),
#  ('Condition2_Feedr', 0.00031205420328472513),
#  ('RoofStyle_Hip', 0.0003119988627955786),
#  ('Street_Grvl', 0.00029853628656492594),
#  ('MasVnrType_None', 0.0002859945056778513),
#  ('BsmtFinType2_BLQ', 0.0002826050902916446),
#  ('SaleType_CWD', 0.0002803504122118595),
#  ('Functional_Min2', 0.0002586362658973862),
#  ('Exterior2nd_Wd Shng', 0.00025145677580195545),
#  ('Condition1_RRAe', 0.0002514417074466489),
#  ('RoofStyle_Gable', 0.00025035064255514693),
#  ('LowQualFinSF', 0.00024033820550861367),
#  ('BsmtFinType1_Rec', 0.00023525037042234687),
#  ('Foundation_PConc', 0.00023505053196683305),
#  ('HeatingQC_Ex', 0.00023448212635841982),
#  ('Foundation_Slab', 0.00022814915725739997),
#  ('Exterior2nd_CBlock', 0.00022505934445039223),
#  ('BsmtCond_Gd', 0.00020321570517172938),
#  ('Neighborhood_SawyerW', 0.00018618286631071217),
#  ('RoofMatl_CompShg', 0.00018530469270102475),
#  ('LotConfig_FR2', 0.00018123342608275547),
#  ('PavedDrive_Y', 0.00016736569647159504),
#  ('Exterior2nd_CmentBd', 0.0001665673086089909),
#  ('KitchenQual_Gd', 0.0001631610301352373),
#  ('HouseStyle_2.5Fin', 0.00016062935107730934),
#  ('HeatingQC_Fa', 0.00015892268473063356),
#  ('Neighborhood_Timber', 0.0001567577234553322),
#  ('FireplaceQu_Po', 0.00015659490172344935),
#  ('HouseStyle_2.5Unf', 0.00014263723025838027),
#  ('GarageFinish_RFn', 0.00014176958508961524),
#  ('Fence_MnPrv', 0.0001386029599211533),
#  ('Neighborhood_StoneBr', 0.00013723032683894077),
#  ('Neighborhood_NAmes', 0.00012633071961736414),
#  ('ExterCond_TA', 0.00012031194614841),
#  ('BsmtHalfBath', 7.326542773336443e-05),
#  ('KitchenQual_Ex', 6.823155911544354e-05),
#  ('Neighborhood_Sawyer', 6.22852644849856e-05),
#  ('BsmtFinType1_ALQ', 6.189494325911123e-05),
#  ('BsmtCond_TA', 4.662907273220614e-05),
#  ('Functional_Typ', 1.936493390980956e-05),
#  ('BsmtFinType2_Unf', 1.7625386594386984e-05),
#  ('ExterQual_Gd', 1.3420451453497524e-06),
#  ('MSZoning_C (all)', 0.0),
#  ('MSZoning_FV', 0.0),
#  ('MSZoning_RH', 0.0),
#  ('Alley_Pave', 0.0),
#  ('LandContour_Bnk', 0.0),
#  ('LandContour_Low', 0.0),
#  ('LandContour_Lvl', 0.0),
#  ('Utilities_AllPub', 0.0),
#  ('Utilities_NoSeWa', 0.0),
#  ('LandSlope_Sev', 0.0),
#  ('Neighborhood_Blmngtn', 0.0),
#  ('Neighborhood_Blueste', 0.0),
#  ('Neighborhood_BrDale', 0.0),
#  ('Neighborhood_BrkSide', 0.0),
#  ('Neighborhood_ClearCr', 0.0),
#  ('Neighborhood_Crawfor', 0.0),
#  ('Neighborhood_Edwards', 0.0),
#  ('Neighborhood_MeadowV', 0.0),
#  ('Neighborhood_Mitchel', 0.0),
#  ('Neighborhood_NPkVill', 0.0),
#  ('Neighborhood_NWAmes', 0.0),
#  ('Neighborhood_OldTown', 0.0),
#  ('Neighborhood_SWISU', 0.0),
#  ('Neighborhood_Somerst', 0.0),
#  ('Neighborhood_Veenker', 0.0),
#  ('Condition1_Artery', 0.0),
#  ('Condition1_PosN', 0.0),
#  ('Condition1_RRNe', 0.0),
#  ('Condition1_RRNn', 0.0),
#  ('Condition2_Artery', 0.0),
#  ('Condition2_Norm', 0.0),
#  ('Condition2_PosA', 0.0),
#  ('Condition2_PosN', 0.0),
#  ('Condition2_RRAe', 0.0),
#  ('Condition2_RRAn', 0.0),
#  ('Condition2_RRNn', 0.0),
#  ('HouseStyle_1.5Unf', 0.0),
#  ('HouseStyle_SFoyer', 0.0),
#  ('RoofStyle_Flat', 0.0),
#  ('RoofStyle_Gambrel', 0.0),
#  ('RoofStyle_Mansard', 0.0),
#  ('RoofStyle_Shed', 0.0),
#  ('RoofMatl_Membran', 0.0),
#  ('RoofMatl_Metal', 0.0),
#  ('RoofMatl_Roll', 0.0),
#  ('RoofMatl_Tar&Grv', 0.0),
#  ('RoofMatl_WdShake', 0.0),
#  ('Exterior1st_AsbShng', 0.0),
#  ('Exterior1st_AsphShn', 0.0),
#  ('Exterior1st_BrkComm', 0.0),
#  ('Exterior1st_BrkFace', 0.0),
#  ('Exterior1st_CemntBd', 0.0),
#  ('Exterior1st_ImStucc', 0.0),
#  ('Exterior1st_Stone', 0.0),
#  ('Exterior1st_VinylSd', 0.0),
#  ('Exterior1st_Wd Sdng', 0.0),
#  ('Exterior1st_WdShing', 0.0),
#  ('Exterior2nd_AsbShng', 0.0),
#  ('Exterior2nd_AsphShn', 0.0),
#  ('Exterior2nd_BrkFace', 0.0),
#  ('Exterior2nd_HdBoard', 0.0),
#  ('Exterior2nd_ImStucc', 0.0),
#  ('Exterior2nd_MetalSd', 0.0),
#  ('Exterior2nd_Other', 0.0),
#  ('Exterior2nd_Stone', 0.0),
#  ('Exterior2nd_VinylSd', 0.0),
#  ('Exterior2nd_Wd Sdng', 0.0),
#  ('MasVnrType_BrkCmn', 0.0),
#  ('MasVnrType_BrkFace', 0.0),
#  ('ExterQual_Ex', 0.0),
#  ('ExterQual_TA', 0.0),
#  ('ExterCond_Ex', 0.0),
#  ('ExterCond_Gd', 0.0),
#  ('ExterCond_Po', 0.0),
#  ('Foundation_Stone', 0.0),
#  ('BsmtQual_DNE', 0.0),
#  ('BsmtQual_Fa', 0.0),
#  ('BsmtQual_TA', 0.0),
#  ('BsmtCond_DNE', 0.0),
#  ('BsmtCond_Fa', 0.0),
#  ('BsmtCond_Po', 0.0),
#  ('BsmtExposure_DNE', 0.0),
#  ('BsmtExposure_Mn', 0.0),
#  ('BsmtFinType1_DNE', 0.0),
#  ('BsmtFinType1_LwQ', 0.0),
#  ('BsmtFinType1_Unf', 0.0),
#  ('BsmtFinType2_ALQ', 0.0),
#  ('BsmtFinType2_DNE', 0.0),
#  ('BsmtFinType2_GLQ', 0.0),
#  ('BsmtFinType2_LwQ', 0.0),
#  ('Heating_Floor', 0.0),
#  ('Heating_GasW', 0.0),
#  ('Heating_OthW', 0.0),
#  ('Heating_Wall', 0.0),
#  ('HeatingQC_Gd', 0.0),
#  ('HeatingQC_Po', 0.0),
#  ('HeatingQC_TA', 0.0),
#  ('CentralAir_Y', 0.0),
#  ('Electrical_FuseF', 0.0),
#  ('Electrical_FuseP', 0.0),
#  ('Electrical_Mix', 0.0),
#  ('Electrical_SBrkr', 0.0),
#  ('KitchenQual_TA', 0.0),
#  ('Functional_Maj1', 0.0),
#  ('Functional_Maj2', 0.0),
#  ('Functional_Min1', 0.0),
#  ('Functional_Mod', 0.0),
#  ('Functional_Sev', 0.0),
#  ('FireplaceQu_DNE', 0.0),
#  ('FireplaceQu_Ex', 0.0),
#  ('FireplaceQu_TA', 0.0),
#  ('GarageType_2Types', 0.0),
#  ('GarageType_BuiltIn', 0.0),
#  ('GarageType_DNE', 0.0),
#  ('GarageFinish_DNE', 0.0),
#  ('GarageFinish_Fin', 0.0),
#  ('GarageQual_Ex', 0.0),
#  ('GarageQual_Fa', 0.0),
#  ('GarageQual_Gd', 0.0),
#  ('GarageQual_Po', 0.0),
#  ('GarageQual_TA', 0.0),
#  ('GarageCond_DNE', 0.0),
#  ('GarageCond_Ex', 0.0),
#  ('GarageCond_Gd', 0.0),
#  ('GarageCond_Po', 0.0),
#  ('GarageCond_TA', 0.0),
#  ('PavedDrive_N', 0.0),
#  ('PoolQC_Fa', 0.0),
#  ('Fence_GdPrv', 0.0),
#  ('Fence_GdWo', 0.0),
#  ('Fence_MnWw', 0.0),
#  ('MiscFeature_DNE', 0.0),
#  ('MiscFeature_Gar2', 0.0),
#  ('MiscFeature_Othr', 0.0),
#  ('MiscFeature_Shed', 0.0),
#  ('MiscFeature_TenC', 0.0),
#  ('SaleType_COD', 0.0),
#  ('SaleType_Con', 0.0),
#  ('SaleType_ConLD', 0.0),
#  ('SaleType_ConLI', 0.0),
#  ('SaleType_ConLw', 0.0),
#  ('SaleType_New', 0.0),
#  ('SaleType_Oth', 0.0),
#  ('SaleType_WD', 0.0),
#  ('SaleCondition_AdjLand', 0.0),
#  ('SaleCondition_Alloca', 0.0),
#  ('SaleCondition_Family', 0.0),
#  ('SaleCondition_Normal', 0.0),
#  ('SaleCondition_Partial', 0.0),
#  ('FullBath', 0.0),
#  ('ScreenPorch', 0.0),
#  ('MiscVal', 0.0)]

# %%
gs_gbm.cv_results_
# Out:
# {'mean_fit_time': array([ 0.89089885,  0.88390298,  0.93370013,  0.94219956,  0.95899916,
#          0.05729995,  0.11120086,  0.48949928,  0.91459923,  1.76539969,
#          4.43939939,  9.02419872, 12.86399999, 14.40939927, 20.20651412,
#          0.07789969,  0.1706996 ,  0.91769929,  0.33970032,  0.62729959,
#          0.91989989,  1.18699975]),
#  'std_fit_time': array([0.0110254 , 0.00666411, 0.04315285, 0.04019036, 0.04396415,
#         0.00280312, 0.00697717, 0.02194559, 0.02251855, 0.02181311,
#         0.04555622, 0.09479812, 0.2364449 , 0.19257824, 0.96822303,
#         0.0026149 , 0.00211211, 0.01273787, 0.00588701, 0.00404508,
#         0.01658728, 0.01653513]),
#  'mean_score_time': array([0.00670004, 0.00619698, 0.00639935, 0.00679917, 0.00690079,
#         0.00659957, 0.0061995 , 0.00710001, 0.00700054, 0.0068007 ,
#         0.00770011, 0.00980139, 0.01100054, 0.01260009, 0.00909986,
#         0.0062993 , 0.00630112, 0.00630064, 0.00600028, 0.00620036,
#         0.00600019, 0.00660143]),
#  'std_score_time': array([5.09987160e-04, 4.00707603e-04, 6.64901730e-04, 1.20847772e-03,
#         1.11339538e-03, 1.19988985e-03, 1.40051909e-03, 2.70926532e-03,
#         1.04971125e-03, 4.00806732e-04, 2.44483976e-04, 2.45282086e-04,
#         1.39510525e-06, 3.32284512e-03, 2.26648567e-03, 2.45125997e-04,
#         2.44854205e-04, 3.99804723e-04, 3.16280483e-04, 5.10201886e-04,
#         1.19304619e-06, 4.89329158e-04]),
#  'param_learning_rate': masked_array(data=[0.0001, 0.001, 0.01, 0.1, 1, --, --, --, --, --, --,
#                     --, --, --, --, --, --, --, --, --, --, --],
#               mask=[False, False, False, False, False,  True,  True,  True,
#                      True,  True,  True,  True,  True,  True,  True,  True,
#                      True,  True,  True,  True,  True,  True],
#         fill_value='?',
#              dtype=object),
#  'param_n_estimators': masked_array(data=[--, --, --, --, --, 5, 10, 50, 100, 200, 500, 1000,
#                     1500, 2000, 5000, --, --, --, --, --, --, --],
#               mask=[ True,  True,  True,  True,  True, False, False, False,
#                     False, False, False, False, False, False, False,  True,
#                      True,  True,  True,  True,  True,  True],
#         fill_value='?',
#              dtype=object),
#  'param_max_features': masked_array(data=[--, --, --, --, --, --, --, --, --, --, --, --, --, --,
#                     --, 9, 40, 302, --, --, --, --],
#               mask=[ True,  True,  True,  True,  True,  True,  True,  True,
#                      True,  True,  True,  True,  True,  True,  True, False,
#                     False, False,  True,  True,  True,  True],
#         fill_value='?',
#              dtype=object),
#  'param_max_depth': masked_array(data=[--, --, --, --, --, --, --, --, --, --, --, --, --, --,
#                     --, --, --, --, 1, 2, 3, 4],
#               mask=[ True,  True,  True,  True,  True,  True,  True,  True,
#                      True,  True,  True,  True,  True,  True,  True,  True,
#                      True,  True, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'learning_rate': 0.0001},
#   {'learning_rate': 0.001},
#   {'learning_rate': 0.01},
#   {'learning_rate': 0.1},
#   {'learning_rate': 1},
#   {'n_estimators': 5},
#   {'n_estimators': 10},
#   {'n_estimators': 50},
#   {'n_estimators': 100},
#   {'n_estimators': 200},
#   {'n_estimators': 500},
#   {'n_estimators': 1000},
#   {'n_estimators': 1500},
#   {'n_estimators': 2000},
#   {'n_estimators': 5000},
#   {'max_features': 9},
#   {'max_features': 40},
#   {'max_features': 302},
#   {'max_depth': 1},
#   {'max_depth': 2},
#   {'max_depth': 3},
#   {'max_depth': 4}],
#  'split0_test_score': array([ 0.00857993,  0.07795316,  0.39107768,  0.52135643, -0.00996828,
#          0.2813504 ,  0.402314  ,  0.54478703,  0.52135643,  0.48990849,
#          0.46686811,  0.45924511,  0.45934599,  0.45934599,  0.45934599,
#          0.57069705,  0.58731261,  0.52135643,  0.55253593,  0.54583749,
#          0.52135643,  0.52597475]),
#  'split1_test_score': array([0.00344184, 0.05612179, 0.31620141, 0.50041794, 0.16468079,
#         0.22189878, 0.32305411, 0.48744835, 0.50041794, 0.50015349,
#         0.49744621, 0.4923906 , 0.49265411, 0.49265411, 0.49265411,
#         0.43873513, 0.48673692, 0.50041794, 0.40937715, 0.45970668,
#         0.50041794, 0.48227489]),
#  'split2_test_score': array([0.0102367 , 0.09514236, 0.50036714, 0.54493512, 0.04234263,
#         0.37788298, 0.52334191, 0.57760497, 0.54493512, 0.52304061,
#         0.49103725, 0.47966992, 0.47921067, 0.47921067, 0.47921067,
#         0.59999887, 0.59038335, 0.54493512, 0.62849222, 0.56028081,
#         0.54493512, 0.59822168]),
#  'split3_test_score': array([0.00958441, 0.09062684, 0.46674349, 0.56292827, 0.41545525,
#         0.33056898, 0.46752369, 0.57220305, 0.56292827, 0.56515715,
#         0.56589188, 0.56489046, 0.565984  , 0.565984  , 0.565984  ,
#         0.55165916, 0.56407742, 0.56292827, 0.547742  , 0.54767297,
#         0.56292827, 0.59124139]),
#  'split4_test_score': array([0.00710123, 0.08033568, 0.4517007 , 0.60761388, 0.04298314,
#         0.32935532, 0.45825966, 0.60560352, 0.60761388, 0.60226641,
#         0.60317613, 0.60081846, 0.59852365, 0.59852365, 0.59852365,
#         0.53113421, 0.6240477 , 0.60761388, 0.54623528, 0.56424135,
#         0.60761388, 0.57308922]),
#  'mean_test_score': array([0.00778882, 0.08003597, 0.42521808, 0.54745033, 0.13109871,
#         0.30821129, 0.43489867, 0.55752938, 0.54745033, 0.53610523,
#         0.52488392, 0.51940291, 0.51914368, 0.51914368, 0.51914368,
#         0.53844488, 0.5705116 , 0.54745033, 0.53687652, 0.53554786,
#         0.54745033, 0.55416039]),
#  'std_test_score': array([0.00241707, 0.01354021, 0.06499734, 0.03676543, 0.15331555,
#         0.05286291, 0.06782817, 0.04000797, 0.03676543, 0.04199683,
#         0.05113821, 0.05408317, 0.05360467, 0.05360467, 0.05360467,
#         0.05477078, 0.04604969, 0.03676543, 0.0708525 , 0.03857412,
#         0.03676543, 0.04390138]),
#  'rank_test_score': array([22, 21, 18,  4, 20, 19, 17,  2,  4, 10, 12, 13, 14, 14, 14,  8,  1,
#          4,  9, 11,  4,  3])}

# %%
gbm_top_important_features = [x[0] for x in gbm_imp_feat if x[1] >= 0.01]

hp_dum_gbm = hp_dum[[*gbm_top_important_features]]
hp_dum_gbm
# Out:
#       LotArea  MSSubClass  1stFlrSF  LotConfig_Corner  GrLivArea  GarageArea  \
# 0        8450          60       856                 0       1710         548
# 1        9600          20      1262                 0       1262         460
# 2       11250          60       920                 0       1786         608
# 3        9550          70       961                 1       1717         642
# 4       14260          60      1145                 0       2198         836
# ...       ...         ...       ...               ...        ...         ...
# 1455     7917          60       953                 0       1647         460
# 1456    13175          20      2073                 0       2073         500
# 1457     9042          70      1188                 0       2340         252
# 1458     9717          20      1078                 0       1078         240
# 1459     9937          20      1256                 0       1256         276
#
#       BldgType_1Fam  BldgType_Twnhs  LotShape_IR3  TotalBsmtSF  \
# 0                 1               0             0          856
# 1                 1               0             0         1262
# 2                 1               0             0          920
# 3                 1               0             0          756
# 4                 1               0             0         1145
# ...             ...             ...           ...          ...
# 1455              1               0             0          953
# 1456              1               0             0         1542
# 1457              1               0             0         1152
# 1458              1               0             0         1078
# 1459              1               0             0         1256
#
#       GarageYrModified  YearBuilt  OverallQual  LotConfig_CulDSac  \
# 0                 2003       2003            7                  0
# 1                 1976       1976            6                  0
# 2                 2001       2001            7                  0
# 3                 1915       1915            7                  0
# 4                 2000       2000            8                  0
# ...                ...        ...          ...                ...
# 1455              1999       1999            6                  0
# 1456              1978       1978            6                  0
# 1457              1941       1941            7                  0
# 1458              1950       1950            5                  0
# 1459              1965       1965            5                  0
#
#       GarageType_Detchd  PoolQC_Gd  PoolQC_DNE  MSZoning_RL  YearRemodAdd  \
# 0                     0          0           1            1          2003
# 1                     0          0           1            1          1976
# 2                     0          0           1            1          2002
# 3                     1          0           1            1          1970
# 4                     0          0           1            1          2000
# ...                 ...        ...         ...          ...           ...
# 1455                  0          0           1            1          2000
# 1456                  0          0           1            1          1988
# 1457                  0          0           1            1          2006
# 1458                  0          0           1            1          1996
# 1459                  0          0           1            1          1965
#
#       OpenPorchSF
# 0              61
# 1               0
# 2              42
# 3              35
# 4              84
# ...           ...
# 1455           40
# 1456            0
# 1457           60
# 1458            0
# 1459           68
#
# [1460 rows x 20 columns]

# %% [markdown]
# ## Try using unscaled dataset to see if there is a difference

# %%
from sklearn.ensemble import GradientBoostingRegressor
gbm = GradientBoostingRegressor(random_state=0, loss='ls',
                                min_impurity_decrease=0.1, 
                                warm_start=False)

learningrate = [0.0001, 0.001, 0.01, 0.1, 1] # subsequently, fine tune
nestimators = [5, 10, 50, 100, 200, 500, 1000,
               1500, 2000, 5000]
# subsamples = np.linspace(0, 1, 100)
maxfeatures = [9, 40, len(xtrain.columns)]
maxdepth = range(1, 5)

ytrain_array = ytrain.values.flatten()

gparam_gbm = [{'learning_rate': learningrate},
              {'n_estimators': nestimators},
#               {'subsample': subsamples}, 
              {'max_features': maxfeatures},
              {'max_depth': maxdepth}]

n_folds=ms.StratifiedKFold(n_splits=5, random_state=0, shuffle=True)

gs_gbm = GridSearchCV(gbm, gparam_gbm, cv=n_folds, refit=True, n_jobs=-1)
# %time gs_gbm.fit(xtrain, ytrain_array)
